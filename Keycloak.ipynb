# %% [markdown]
# <a href="https://colab.research.google.com/github/rhyamada/keycloak_frontchannel_logout_test/blob/main/Keycloak.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install openjdk-8-jdk-headless maven
# !git clone https://github.com/rhyamada/keycloak.git
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libaopalliance-java libapache-pom-java libatinject-jsr330-api-java
#   libcdi-api-java libcommons-cli-java libcommons-io-java libcommons-lang3-java
#   libcommons-parent-java libgeronimo-annotation-1.3-spec-java
#   libgeronimo-interceptor-3.0-spec-java libguava-java libguice-java
#   libhawtjni-runtime-java libjansi-java libjansi-native-java libjsr305-java
#   libmaven-parent-java libmaven-resolver-java libmaven-shared-utils-java
#   libmaven3-core-java libplexus-cipher-java libplexus-classworlds-java
#   libplexus-component-annotations-java libplexus-interpolation-java
#   libplexus-sec-dispatcher-java libplexus-utils2-java libsisu-inject-java
#   libsisu-plexus-java libslf4j-java libwagon-file-java
#   libwagon-http-shaded-java libwagon-provider-api-java openjdk-8-jre-headless
# Suggested packages:
#   libaopalliance-java-doc libatinject-jsr330-api-java-doc libservlet3.1-java
#   libcommons-io-java-doc libcommons-lang3-java-doc libasm-java libcglib-java
#   libjsr305-java-doc libmaven-shared-utils-java-doc liblogback-java
#   libplexus-cipher-java-doc libplexus-classworlds-java-doc
#   libplexus-interpolation-java-doc libplexus-sec-dispatcher-java-doc
#   libplexus-utils2-java-doc junit4 testng libcommons-logging-java
#   liblog4j1.2-java openjdk-8-demo openjdk-8-source libnss-mdns
#   fonts-dejavu-extra fonts-ipafont-gothic fonts-ipafont-mincho
#   fonts-wqy-microhei fonts-wqy-zenhei fonts-indic
# The following NEW packages will be installed:
#   libaopalliance-java libapache-pom-java libatinject-jsr330-api-java
#   libcdi-api-java libcommons-cli-java libcommons-io-java libcommons-lang3-java
#   libcommons-parent-java libgeronimo-annotation-1.3-spec-java
#   libgeronimo-interceptor-3.0-spec-java libguava-java libguice-java
#   libhawtjni-runtime-java libjansi-java libjansi-native-java libjsr305-java
#   libmaven-parent-java libmaven-resolver-java libmaven-shared-utils-java
#   libmaven3-core-java libplexus-cipher-java libplexus-classworlds-java
#   libplexus-component-annotations-java libplexus-interpolation-java
#   libplexus-sec-dispatcher-java libplexus-utils2-java libsisu-inject-java
#   libsisu-plexus-java libslf4j-java libwagon-file-java
#   libwagon-http-shaded-java libwagon-provider-api-java maven
#   openjdk-8-jdk-headless openjdk-8-jre-headless
# 0 upgraded, 35 newly installed, 0 to remove and 39 not upgraded.
# Need to get 45.4 MB of archives.
# After this operation, 155 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libapache-pom-java all 18-1 [4,720 B]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libatinject-jsr330-api-java all 1.0+ds1-5 [5,348 B]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgeronimo-interceptor-3.0-spec-java all 1.0.1-4fakesync [8,616 B]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libcdi-api-java all 1.2-2 [54.5 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libcommons-cli-java all 1.4-1 [53.8 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libcommons-parent-java all 43-1 [10.8 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libcommons-io-java all 2.6-2 [198 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libcommons-lang3-java all 3.8-1~18.04.2 [479 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgeronimo-annotation-1.3-spec-java all 1.0-1 [10.7 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libjsr305-java all 0.1~+svn49-10 [26.5 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libguava-java all 19.0-1 [2,028 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libaopalliance-java all 20070526-6 [9,084 B]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libguice-java all 4.0-4 [853 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libhawtjni-runtime-java all 1.15-2 [27.1 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libjansi-native-java all 1.7-1 [19.4 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libjansi-java all 1.16-1 [36.2 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libmaven-parent-java all 31-2~18.04 [5,196 B]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libplexus-utils2-java all 3.0.24-3 [246 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libwagon-provider-api-java all 3.0.0-2 [48.2 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libmaven-resolver-java all 1.3.1-1~18.04 [549 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libmaven-shared-utils-java all 3.3.0-1~18.04 [149 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libplexus-cipher-java all 1.7-3 [15.1 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libplexus-classworlds-java all 2.5.2-2 [49.3 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libplexus-component-annotations-java all 1.7.1-7 [6,596 B]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libplexus-interpolation-java all 1.24-1 [73.4 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libplexus-sec-dispatcher-java all 1.4-3 [28.0 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libslf4j-java all 1.7.25-3 [141 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsisu-inject-java all 0.3.2-2 [346 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsisu-plexus-java all 0.3.3-3 [182 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libmaven3-core-java all 3.6.0-1~18.04.1 [1,465 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libwagon-file-java all 3.0.0-2 [7,960 B]
# Get:32 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libwagon-http-shaded-java all 3.0.0-2 [1,757 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 openjdk-8-jre-headless amd64 8u292-b10-0ubuntu1~18.04 [28.2 MB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 maven all 3.6.0-1~18.04.1 [22.4 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 openjdk-8-jdk-headless amd64 8u292-b10-0ubuntu1~18.04 [8,284 kB]
# Fetched 45.4 MB in 4s (11.8 MB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package libapache-pom-java.
# (Reading database ... 160772 files and directories currently installed.)
# Preparing to unpack .../00-libapache-pom-java_18-1_all.deb ...
# Unpacking libapache-pom-java (18-1) ...
# Selecting previously unselected package libatinject-jsr330-api-java.
# Preparing to unpack .../01-libatinject-jsr330-api-java_1.0+ds1-5_all.deb ...
# Unpacking libatinject-jsr330-api-java (1.0+ds1-5) ...
# Selecting previously unselected package libgeronimo-interceptor-3.0-spec-java.
# Preparing to unpack .../02-libgeronimo-interceptor-3.0-spec-java_1.0.1-4fakesync_all.deb ...
# Unpacking libgeronimo-interceptor-3.0-spec-java (1.0.1-4fakesync) ...
# Selecting previously unselected package libcdi-api-java.
# Preparing to unpack .../03-libcdi-api-java_1.2-2_all.deb ...
# Unpacking libcdi-api-java (1.2-2) ...
# Selecting previously unselected package libcommons-cli-java.
# Preparing to unpack .../04-libcommons-cli-java_1.4-1_all.deb ...
# Unpacking libcommons-cli-java (1.4-1) ...
# Selecting previously unselected package libcommons-parent-java.
# Preparing to unpack .../05-libcommons-parent-java_43-1_all.deb ...
# Unpacking libcommons-parent-java (43-1) ...
# Selecting previously unselected package libcommons-io-java.
# Preparing to unpack .../06-libcommons-io-java_2.6-2_all.deb ...
# Unpacking libcommons-io-java (2.6-2) ...
# Selecting previously unselected package libcommons-lang3-java.
# Preparing to unpack .../07-libcommons-lang3-java_3.8-1~18.04.2_all.deb ...
# Unpacking libcommons-lang3-java (3.8-1~18.04.2) ...
# Selecting previously unselected package libgeronimo-annotation-1.3-spec-java.
# Preparing to unpack .../08-libgeronimo-annotation-1.3-spec-java_1.0-1_all.deb ...
# Unpacking libgeronimo-annotation-1.3-spec-java (1.0-1) ...
# Selecting previously unselected package libjsr305-java.
# Preparing to unpack .../09-libjsr305-java_0.1~+svn49-10_all.deb ...
# Unpacking libjsr305-java (0.1~+svn49-10) ...
# Selecting previously unselected package libguava-java.
# Preparing to unpack .../10-libguava-java_19.0-1_all.deb ...
# Unpacking libguava-java (19.0-1) ...
# Selecting previously unselected package libaopalliance-java.
# Preparing to unpack .../11-libaopalliance-java_20070526-6_all.deb ...
# Unpacking libaopalliance-java (20070526-6) ...
# Selecting previously unselected package libguice-java.
# Preparing to unpack .../12-libguice-java_4.0-4_all.deb ...
# Unpacking libguice-java (4.0-4) ...
# Selecting previously unselected package libhawtjni-runtime-java.
# Preparing to unpack .../13-libhawtjni-runtime-java_1.15-2_all.deb ...
# Unpacking libhawtjni-runtime-java (1.15-2) ...
# Selecting previously unselected package libjansi-native-java.
# Preparing to unpack .../14-libjansi-native-java_1.7-1_all.deb ...
# Unpacking libjansi-native-java (1.7-1) ...
# Selecting previously unselected package libjansi-java.
# Preparing to unpack .../15-libjansi-java_1.16-1_all.deb ...
# Unpacking libjansi-java (1.16-1) ...
# Selecting previously unselected package libmaven-parent-java.
# Preparing to unpack .../16-libmaven-parent-java_31-2~18.04_all.deb ...
# Unpacking libmaven-parent-java (31-2~18.04) ...
# Selecting previously unselected package libplexus-utils2-java.
# Preparing to unpack .../17-libplexus-utils2-java_3.0.24-3_all.deb ...
# Unpacking libplexus-utils2-java (3.0.24-3) ...
# Selecting previously unselected package libwagon-provider-api-java.
# Preparing to unpack .../18-libwagon-provider-api-java_3.0.0-2_all.deb ...
# Unpacking libwagon-provider-api-java (3.0.0-2) ...
# Selecting previously unselected package libmaven-resolver-java.
# Preparing to unpack .../19-libmaven-resolver-java_1.3.1-1~18.04_all.deb ...
# Unpacking libmaven-resolver-java (1.3.1-1~18.04) ...
# Selecting previously unselected package libmaven-shared-utils-java.
# Preparing to unpack .../20-libmaven-shared-utils-java_3.3.0-1~18.04_all.deb ...
# Unpacking libmaven-shared-utils-java (3.3.0-1~18.04) ...
# Selecting previously unselected package libplexus-cipher-java.
# Preparing to unpack .../21-libplexus-cipher-java_1.7-3_all.deb ...
# Unpacking libplexus-cipher-java (1.7-3) ...
# Selecting previously unselected package libplexus-classworlds-java.
# Preparing to unpack .../22-libplexus-classworlds-java_2.5.2-2_all.deb ...
# Unpacking libplexus-classworlds-java (2.5.2-2) ...
# Selecting previously unselected package libplexus-component-annotations-java.
# Preparing to unpack .../23-libplexus-component-annotations-java_1.7.1-7_all.deb ...
# Unpacking libplexus-component-annotations-java (1.7.1-7) ...
# Selecting previously unselected package libplexus-interpolation-java.
# Preparing to unpack .../24-libplexus-interpolation-java_1.24-1_all.deb ...
# Unpacking libplexus-interpolation-java (1.24-1) ...
# Selecting previously unselected package libplexus-sec-dispatcher-java.
# Preparing to unpack .../25-libplexus-sec-dispatcher-java_1.4-3_all.deb ...
# Unpacking libplexus-sec-dispatcher-java (1.4-3) ...
# Selecting previously unselected package libslf4j-java.
# Preparing to unpack .../26-libslf4j-java_1.7.25-3_all.deb ...
# Unpacking libslf4j-java (1.7.25-3) ...
# Selecting previously unselected package libsisu-inject-java.
# Preparing to unpack .../27-libsisu-inject-java_0.3.2-2_all.deb ...
# Unpacking libsisu-inject-java (0.3.2-2) ...
# Selecting previously unselected package libsisu-plexus-java.
# Preparing to unpack .../28-libsisu-plexus-java_0.3.3-3_all.deb ...
# Unpacking libsisu-plexus-java (0.3.3-3) ...
# Selecting previously unselected package libmaven3-core-java.
# Preparing to unpack .../29-libmaven3-core-java_3.6.0-1~18.04.1_all.deb ...
# Unpacking libmaven3-core-java (3.6.0-1~18.04.1) ...
# Selecting previously unselected package libwagon-file-java.
# Preparing to unpack .../30-libwagon-file-java_3.0.0-2_all.deb ...
# Unpacking libwagon-file-java (3.0.0-2) ...
# Selecting previously unselected package libwagon-http-shaded-java.
# Preparing to unpack .../31-libwagon-http-shaded-java_3.0.0-2_all.deb ...
# Unpacking libwagon-http-shaded-java (3.0.0-2) ...
# Selecting previously unselected package openjdk-8-jre-headless:amd64.
# Preparing to unpack .../32-openjdk-8-jre-headless_8u292-b10-0ubuntu1~18.04_amd64.deb ...
# Unpacking openjdk-8-jre-headless:amd64 (8u292-b10-0ubuntu1~18.04) ...
# Selecting previously unselected package maven.
# Preparing to unpack .../33-maven_3.6.0-1~18.04.1_all.deb ...
# Unpacking maven (3.6.0-1~18.04.1) ...
# Selecting previously unselected package openjdk-8-jdk-headless:amd64.
# Preparing to unpack .../34-openjdk-8-jdk-headless_8u292-b10-0ubuntu1~18.04_amd64.deb ...
# Unpacking openjdk-8-jdk-headless:amd64 (8u292-b10-0ubuntu1~18.04) ...
# Setting up libslf4j-java (1.7.25-3) ...
# Setting up libplexus-classworlds-java (2.5.2-2) ...
# Setting up libhawtjni-runtime-java (1.15-2) ...
# Setting up libplexus-cipher-java (1.7-3) ...
# Setting up libplexus-interpolation-java (1.24-1) ...
# Setting up libplexus-component-annotations-java (1.7.1-7) ...
# Setting up libplexus-utils2-java (3.0.24-3) ...
# Setting up libwagon-provider-api-java (3.0.0-2) ...
# Setting up libjsr305-java (0.1~+svn49-10) ...
# Setting up libgeronimo-interceptor-3.0-spec-java (1.0.1-4fakesync) ...
# Setting up libmaven-resolver-java (1.3.1-1~18.04) ...
# Setting up libjansi-native-java (1.7-1) ...
# Setting up libwagon-http-shaded-java (3.0.0-2) ...
# Setting up libapache-pom-java (18-1) ...
# Setting up libatinject-jsr330-api-java (1.0+ds1-5) ...
# Setting up libmaven-parent-java (31-2~18.04) ...
# Setting up libaopalliance-java (20070526-6) ...
# Setting up libgeronimo-annotation-1.3-spec-java (1.0-1) ...
# Setting up libcommons-cli-java (1.4-1) ...
# Setting up libplexus-sec-dispatcher-java (1.4-3) ...
# Setting up openjdk-8-jre-headless:amd64 (8u292-b10-0ubuntu1~18.04) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/orbd to provide /usr/bin/orbd (orbd) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/servertool to provide /usr/bin/servertool (servertool) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/tnameserv to provide /usr/bin/tnameserv (tnameserv) in auto mode
# Setting up openjdk-8-jdk-headless:amd64 (8u292-b10-0ubuntu1~18.04) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/idlj to provide /usr/bin/idlj (idlj) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/wsimport to provide /usr/bin/wsimport (wsimport) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/jsadebugd to provide /usr/bin/jsadebugd (jsadebugd) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/native2ascii to provide /usr/bin/native2ascii (native2ascii) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/javah to provide /usr/bin/javah (javah) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/hsdb to provide /usr/bin/hsdb (hsdb) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/clhsdb to provide /usr/bin/clhsdb (clhsdb) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/extcheck to provide /usr/bin/extcheck (extcheck) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/schemagen to provide /usr/bin/schemagen (schemagen) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/xjc to provide /usr/bin/xjc (xjc) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/jhat to provide /usr/bin/jhat (jhat) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/wsgen to provide /usr/bin/wsgen (wsgen) in auto mode
# Setting up libjansi-java (1.16-1) ...
# Setting up libguava-java (19.0-1) ...
# Setting up libwagon-file-java (3.0.0-2) ...
# Setting up libcommons-parent-java (43-1) ...
# Setting up libcdi-api-java (1.2-2) ...
# Setting up libcommons-lang3-java (3.8-1~18.04.2) ...
# Setting up libcommons-io-java (2.6-2) ...
# Setting up libguice-java (4.0-4) ...
# Setting up libmaven-shared-utils-java (3.3.0-1~18.04) ...
# Setting up libsisu-inject-java (0.3.2-2) ...
# Setting up libsisu-plexus-java (0.3.3-3) ...
# Setting up libmaven3-core-java (3.6.0-1~18.04.1) ...
# Setting up maven (3.6.0-1~18.04.1) ...
# update-alternatives: using /usr/share/maven/bin/mvn to provide /usr/bin/mvn (mvn) in auto mode
# Cloning into 'keycloak'...
# remote: Enumerating objects: 494328, done.
# remote: Counting objects: 100% (2/2), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 494328 (delta 0), reused 0 (delta 0), pack-reused 494326
# Receiving objects: 100% (494328/494328), 157.18 MiB | 22.50 MiB/s, done.
# Resolving deltas: 100% (212480/212480), done.
# Checking out files: 100% (10396/10396), done.

# %%
# !cd keycloak && mvn clean install -DskipTests=true -q
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by com.google.inject.internal.cglib.core.$ReflectUtils$1 (file:/usr/share/maven/lib/guice.jar) to method java.lang.ClassLoader.defineClass(java.lang.String,byte[],int,int,java.security.ProtectionDomain)
# WARNING: Please consider reporting this to the maintainers of com.google.inject.internal.cglib.core.$ReflectUtils$1
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# [info] Copying manifest...
# [info] Copying manifest...
# Loading 99 Mb [▒▒▒▒▒▒▒▒▒▒]

# %%
# !cd keycloak/distribution && mvn clean install -DskipTests=true -q
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by com.google.inject.internal.cglib.core.$ReflectUtils$1 (file:/usr/share/maven/lib/guice.jar) to method java.lang.ClassLoader.defineClass(java.lang.String,byte[],int,int,java.security.ProtectionDomain)
# WARNING: Please consider reporting this to the maintainers of com.google.inject.internal.cglib.core.$ReflectUtils$1
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Jun 07, 2021 1:22:14 PM org.wildfly.core.embedded.LoggerContext$JBossLoggingModuleLogger greeting
# INFO: JBoss Modules version 1.11.0.Final
# Jun 07, 2021 1:22:14 PM org.jboss.msc.service.ServiceContainerImpl <clinit>
# INFO: JBoss MSC version 1.4.12.Final
# Jun 07, 2021 1:22:14 PM org.jboss.threads.Version <clinit>
# INFO: JBoss Threads version 2.4.0.Final
# Jun 07, 2021 1:22:14 PM org.jboss.as.server.ApplicationServerService start
# INFO: WFLYSRV0049: WildFly Core 15.0.1.Final starting
# Jun 07, 2021 1:22:15 PM org.wildfly.security.Version <clinit>
# INFO: ELY00001: WildFly Elytron version 1.15.3.Final
# Jun 07, 2021 1:22:16 PM org.jboss.as.controller.extension.ExtensionRegistry$ExtensionContextImpl registerSubsystem
# INFO: WFLYCTL0033: Extension 'xts' is deprecated and may not be supported in future versions
# Jun 07, 2021 1:22:16 PM org.jboss.as.controller.extension.ExtensionRegistry$ExtensionContextImpl registerSubsystem
# INFO: WFLYCTL0033: Extension 'security' is deprecated and may not be supported in future versions
# Jun 07, 2021 1:22:16 PM org.jboss.as.controller.extension.ExtensionRegistry$ExtensionContextImpl registerSubsystem
# INFO: WFLYCTL0033: Extension 'picketlink-identity-management' is deprecated and may not be supported in future versions
# Jun 07, 2021 1:22:16 PM org.jboss.as.controller.extension.ExtensionRegistry$ExtensionContextImpl registerSubsystem
# INFO: WFLYCTL0033: Extension 'picketlink-federation' is deprecated and may not be supported in future versions
# Jun 07, 2021 1:22:17 PM org.jboss.as.patching.installation.InstallationManagerService start
# INFO: WFLYPAT0050: WildFly cumulative patch ID is: base, one-off patches include: none
# Jun 07, 2021 1:22:17 PM org.jboss.as.server.suspend.SuspendController resume
# INFO: WFLYSRV0212: Resuming server
# Jun 07, 2021 1:22:17 PM org.jboss.as.server.BootstrapListener done
# INFO: WFLYSRV0025: WildFly Core 15.0.1.Final started in 3121ms - Started 29 of 32 services (3 services are lazy, passive or on-demand)
# Jun 07, 2021 1:22:18 PM org.jboss.as.server.ApplicationServerService stop
# INFO: WFLYSRV0050: WildFly Core 15.0.1.Final stopped in 26ms
# [debug] execute contextualize

# %%
# !cd keycloak && mvn -f testsuite/integration-arquillian/pom.xml clean install -Dtest=forms.LogoutTest#frontChannelLogout
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by com.google.inject.internal.cglib.core.$ReflectUtils$1 (file:/usr/share/maven/lib/guice.jar) to method java.lang.ClassLoader.defineClass(java.lang.String,byte[],int,int,java.security.ProtectionDomain)
# WARNING: Please consider reporting this to the maintainers of com.google.inject.internal.cglib.core.$ReflectUtils$1
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# [INFO] Scanning for projects...
# [INFO] ------------------------------------------------------------------------
# [INFO] Reactor Build Order:
# [INFO]
# [INFO] Keycloak Arquillian Integration TestSuite                          [pom]
# [INFO] Test apps                                                          [pom]
# [INFO] Test apps distribution                                             [jar]
# [INFO] Keycloak Authz: PhotoZ  Test Parent                                [pom]
# [INFO] Keycloak Authz Test: Photoz RESTful API                            [war]
# [INFO] Keycloak Authz Tests: Photoz HTML5 Client                          [war]
# [INFO] Keycloak Authz Tests: Hello World Example                          [war]
# [INFO] Keycloak Authz: Servlet Authorization Test                         [war]
# [INFO] Keycloak Authz: Simple Servlet App with Policy Enforcer            [war]
# [INFO] integration-arquillian-test-apps-servlets                          [jar]
# [INFO] Keycloak Test App Profile JEE                                      [war]
# [INFO] integration-arquillian-test-apps-cors-parent                       [pom]
# [INFO] Angular Product Portal JS                                          [war]
# [INFO] JAX-RS Database Service Using OAuth Bearer Tokens                  [war]
# [INFO] Fuse Test Applications                                             [pom]
# [INFO] Customer Portal - Secured in Karaf/Fuse                            [war]
# [INFO] CXF JAXRS Example - Secured in Karaf/Fuse                       [bundle]
# [INFO] CXF JAXRS Example - Secured in Karaf/Fuse 7 on Undertow         [bundle]
# [INFO] CXF JAXWS Example - Secured in Karaf/Fuse                       [bundle]
# [INFO] CXF JAXWS Example - Secured in Karaf/Fuse 7 on Undertow         [bundle]
# [INFO] Product Portal - Secured in Karaf/Fuse                          [bundle]
# [INFO] Product Portal - Secured in Karaf/Fuse 7 on Undertow            [bundle]
# [INFO] Camel endpoint example - Secured in Karaf/Fuse                  [bundle]
# [INFO] Camel endpoint example - Secured in Karaf/Fuse 7.0 on Undertow  [bundle]
# [INFO] Keycloak Fuse Example - Features                                   [jar]
# [INFO] Keycloak Examples - External Config                                [war]
# [INFO] spring-boot-adapter-app                                            [jar]
# [INFO] Servers                                                            [pom]
# [INFO] Auth Server                                                        [pom]
# [INFO] Auth Server Services                                               [pom]
# [INFO] Auth Server Services - Testsuite Providers                         [jar]
# [INFO] Auth Server - JBoss                                                [pom]
# [INFO] Test Util                                                          [jar]
# [INFO] Auth Server - Undertow                                             [jar]
# [INFO] App Server                                                         [pom]
# [INFO] App Server - SPI                                                   [jar]
# [INFO] App Server - JBoss                                                 [pom]
# [INFO] App Server - Karaf                                                 [pom]
# [INFO] App Server - Tomcat                                                [pom]
# [INFO] App Server - Undertow                                              [jar]
# [INFO] App Server - Jetty Parent                                          [pom]
# [INFO] Cache Server                                                       [pom]
# [INFO] Cache Server - JBoss Family                                        [pom]
# [INFO] Tests                                                              [pom]
# [INFO] Base TestSuite                                                     [jar]
# [INFO] Other Tests Modules                                                [pom]
# [INFO] Adapter Tests                                                      [pom]
# [INFO] Adapter Tests - JBoss                                              [pom]
# [INFO] Adapter Tests - Karaf                                              [pom]
# [INFO] Adapter Tests - WAS                                                [pom]
# [INFO] Adapter Tests - WLS                                                [pom]
# [INFO] SSSD tests                                                         [jar]
# [INFO]
# [INFO] -----------< org.keycloak.testsuite:integration-arquillian >------------
# [INFO] Building Keycloak Arquillian Integration TestSuite 14.0.0-SNAPSHOT [1/52]
# [INFO] --------------------------------[ pom ]---------------------------------
# [INFO]
# [INFO] --- maven-clean-plugin:3.1.0:clean (default-clean) @ integration-arquillian ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-java-version) @ integration-arquillian ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven-version) @ integration-arquillian ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven) @ integration-arquillian ---
# [INFO]
# [INFO] --- buildnumber-maven-plugin:1.4:create (get-scm-revision) @ integration-arquillian ---
# [INFO] Executing: /bin/sh -c cd '/content/keycloak/testsuite/integration-arquillian' && 'git' 'rev-parse' '--verify' 'HEAD'
# [INFO] Working directory: /content/keycloak/testsuite/integration-arquillian
# [INFO] Storing buildNumber: 04c2f3697cc46843d789b3471706cbf9abcbf8bb at timestamp: 1623072209768
# [INFO] Storing buildScmBranch: master
# [INFO]
# [INFO] --- maven-source-plugin:3.1.0:jar-no-fork (attach-sources) @ integration-arquillian ---
# [INFO]
# [INFO] --- maven-install-plugin:2.5.2:install (default-install) @ integration-arquillian ---
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/pom.xml to /root/.m2/repository/org/keycloak/testsuite/integration-arquillian/14.0.0-SNAPSHOT/integration-arquillian-14.0.0-SNAPSHOT.pom
# [INFO]
# [INFO] ------< org.keycloak.testsuite:integration-arquillian-test-apps >-------
# [INFO] Building Test apps 14.0.0-SNAPSHOT                                [2/52]
# [INFO] --------------------------------[ pom ]---------------------------------
# [INFO]
# [INFO] --- maven-clean-plugin:3.1.0:clean (default-clean) @ integration-arquillian-test-apps ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-java-version) @ integration-arquillian-test-apps ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven-version) @ integration-arquillian-test-apps ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven) @ integration-arquillian-test-apps ---
# [INFO]
# [INFO] --- buildnumber-maven-plugin:1.4:create (get-scm-revision) @ integration-arquillian-test-apps ---
# [INFO]
# [INFO] --- maven-source-plugin:3.1.0:jar-no-fork (attach-sources) @ integration-arquillian-test-apps ---
# [INFO]
# [INFO] --- maven-install-plugin:2.5.2:install (default-install) @ integration-arquillian-test-apps ---
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/test-apps/pom.xml to /root/.m2/repository/org/keycloak/testsuite/integration-arquillian-test-apps/14.0.0-SNAPSHOT/integration-arquillian-test-apps-14.0.0-SNAPSHOT.pom
# [INFO]
# [INFO] ----< org.keycloak.testsuite:integration-arquillian-test-apps-dist >----
# [INFO] Building Test apps distribution 14.0.0-SNAPSHOT                   [3/52]
# [INFO] --------------------------------[ jar ]---------------------------------
# [INFO]
# [INFO] --- maven-clean-plugin:3.1.0:clean (default-clean) @ integration-arquillian-test-apps-dist ---
# [INFO] Deleting /content/keycloak/testsuite/integration-arquillian/test-apps/test-apps-dist/target
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-java-version) @ integration-arquillian-test-apps-dist ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven-version) @ integration-arquillian-test-apps-dist ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven) @ integration-arquillian-test-apps-dist ---
# [INFO]
# [INFO] --- buildnumber-maven-plugin:1.4:create (get-scm-revision) @ integration-arquillian-test-apps-dist ---
# [INFO]
# [INFO] --- maven-resources-plugin:3.0.1:resources (default-resources) @ integration-arquillian-test-apps-dist ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /content/keycloak/testsuite/integration-arquillian/test-apps/test-apps-dist/src/main/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.8.1-jboss-1:compile (default-compile) @ integration-arquillian-test-apps-dist ---
# [INFO] No sources to compile
# [INFO]
# [INFO] --- maven-antrun-plugin:1.8:run (build-test-apps) @ integration-arquillian-test-apps-dist ---
# [INFO] Executing tasks
#
# main:
#
# all:
#      [copy] Copying 26 files to /content/keycloak/testsuite/integration-arquillian/test-apps/test-apps-dist/target/test-apps/photoz
#      [copy] Copying 8 files to /content/keycloak/testsuite/integration-arquillian/test-apps/test-apps-dist/target/test-apps/hello-world-authz-service
#      [copy] Copying 31 files to /content/keycloak/testsuite/integration-arquillian/test-apps/test-apps-dist/target/test-apps/servlet-authz-app
#      [copy] Copying 9 files to /content/keycloak/testsuite/integration-arquillian/test-apps/test-apps-dist/target/test-apps/servlet-policy-enforcer
#      [copy] Copying 28 files to /content/keycloak/testsuite/integration-arquillian/test-apps/test-apps-dist/target/test-apps/cors
#      [copy] Copying 72 files to /content/keycloak/testsuite/integration-arquillian/test-apps/test-apps-dist/target/test-apps/fuse
# [INFO] Executed tasks
# [INFO]
# [INFO] --- maven-resources-plugin:3.0.1:testResources (default-testResources) @ integration-arquillian-test-apps-dist ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /content/keycloak/testsuite/integration-arquillian/test-apps/test-apps-dist/src/test/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.8.1-jboss-1:testCompile (default-testCompile) @ integration-arquillian-test-apps-dist ---
# [INFO] No sources to compile
# [INFO]
# [INFO] --- maven-surefire-plugin:2.22.2:test (default-test) @ integration-arquillian-test-apps-dist ---
# [INFO] No tests to run.
# [INFO]
# [INFO] --- maven-jar-plugin:3.1.2:jar (default-jar) @ integration-arquillian-test-apps-dist ---
# [WARNING] JAR will be empty - no content was marked for inclusion!
# [INFO] Building jar: /content/keycloak/testsuite/integration-arquillian/test-apps/test-apps-dist/target/test-apps-dist.jar
# [INFO]
# [INFO] --- maven-source-plugin:3.1.0:jar-no-fork (attach-sources) @ integration-arquillian-test-apps-dist ---
# [INFO] No sources in project. Archive not created.
# [INFO]
# [INFO] --- maven-assembly-plugin:3.1.1:single (assemble) @ integration-arquillian-test-apps-dist ---
# [INFO] Reading assembly descriptor: assembly.xml
# [INFO] Building zip: /content/keycloak/testsuite/integration-arquillian/test-apps/test-apps-dist/target/test-apps-dist.zip
# [INFO]
# [INFO] --- maven-install-plugin:2.5.2:install (default-install) @ integration-arquillian-test-apps-dist ---
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/test-apps/test-apps-dist/target/test-apps-dist.jar to /root/.m2/repository/org/keycloak/testsuite/integration-arquillian-test-apps-dist/14.0.0-SNAPSHOT/integration-arquillian-test-apps-dist-14.0.0-SNAPSHOT.jar
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/test-apps/test-apps-dist/pom.xml to /root/.m2/repository/org/keycloak/testsuite/integration-arquillian-test-apps-dist/14.0.0-SNAPSHOT/integration-arquillian-test-apps-dist-14.0.0-SNAPSHOT.pom
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/test-apps/test-apps-dist/target/test-apps-dist.zip to /root/.m2/repository/org/keycloak/testsuite/integration-arquillian-test-apps-dist/14.0.0-SNAPSHOT/integration-arquillian-test-apps-dist-14.0.0-SNAPSHOT.zip
# [INFO]
# [INFO] --< org.keycloak.testsuite:integration-arquillian-test-apps-photoz-parent >--
# [INFO] Building Keycloak Authz: PhotoZ  Test Parent 14.0.0-SNAPSHOT      [4/52]
# [INFO] --------------------------------[ pom ]---------------------------------
# [INFO]
# [INFO] --- maven-clean-plugin:3.1.0:clean (default-clean) @ integration-arquillian-test-apps-photoz-parent ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-java-version) @ integration-arquillian-test-apps-photoz-parent ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven-version) @ integration-arquillian-test-apps-photoz-parent ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven) @ integration-arquillian-test-apps-photoz-parent ---
# [INFO]
# [INFO] --- buildnumber-maven-plugin:1.4:create (get-scm-revision) @ integration-arquillian-test-apps-photoz-parent ---
# [INFO]
# [INFO] --- maven-source-plugin:3.1.0:jar-no-fork (attach-sources) @ integration-arquillian-test-apps-photoz-parent ---
# [INFO]
# [INFO] --- maven-install-plugin:2.5.2:install (default-install) @ integration-arquillian-test-apps-photoz-parent ---
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/test-apps/photoz/pom.xml to /root/.m2/repository/org/keycloak/testsuite/integration-arquillian-test-apps-photoz-parent/14.0.0-SNAPSHOT/integration-arquillian-test-apps-photoz-parent-14.0.0-SNAPSHOT.pom
# [INFO]
# [INFO] -------------< org.keycloak.testsuite:photoz-restful-api >--------------
# [INFO] Building Keycloak Authz Test: Photoz RESTful API 14.0.0-SNAPSHOT  [5/52]
# [INFO] --------------------------------[ war ]---------------------------------
# Downloading from central: https://repo.maven.apache.org/maven2/org/jboss/jboss-parent/10/jboss-parent-10.pom
# Downloaded from central: https://repo.maven.apache.org/maven2/org/jboss/jboss-parent/10/jboss-parent-10.pom (0 B at 0 B/s)
# [INFO]
# [INFO] --- maven-clean-plugin:3.1.0:clean (default-clean) @ photoz-restful-api ---
# [INFO] Deleting /content/keycloak/testsuite/integration-arquillian/test-apps/photoz/photoz-restful-api/target
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-java-version) @ photoz-restful-api ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven-version) @ photoz-restful-api ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven) @ photoz-restful-api ---
# [INFO]
# [INFO] --- buildnumber-maven-plugin:1.4:create (get-scm-revision) @ photoz-restful-api ---
# [INFO]
# [INFO] --- maven-resources-plugin:3.0.1:resources (default-resources) @ photoz-restful-api ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] Copying 1 resource
# [INFO]
# [INFO] --- maven-compiler-plugin:3.8.1-jboss-1:compile (default-compile) @ photoz-restful-api ---
# [INFO] Changes detected - recompiling the module!
# [INFO] Compiling 9 source files to /content/keycloak/testsuite/integration-arquillian/test-apps/photoz/photoz-restful-api/target/classes
# [WARNING] bootstrap class path not set in conjunction with -source 7
# [INFO]
# [INFO] --- maven-resources-plugin:3.0.1:testResources (default-testResources) @ photoz-restful-api ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /content/keycloak/testsuite/integration-arquillian/test-apps/photoz/photoz-restful-api/src/test/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.8.1-jboss-1:testCompile (default-testCompile) @ photoz-restful-api ---
# [INFO] No sources to compile
# [INFO]
# [INFO] --- maven-surefire-plugin:2.22.2:test (default-test) @ photoz-restful-api ---
# [INFO] No tests to run.
# [INFO]
# [INFO] --- maven-war-plugin:3.0.0:war (default-war) @ photoz-restful-api ---
# [INFO] Packaging webapp
# [INFO] Assembling webapp [photoz-restful-api] in [/content/keycloak/testsuite/integration-arquillian/test-apps/photoz/photoz-restful-api/target/photoz-restful-api]
# [INFO] Processing war project
# [INFO] Copying webapp resources [/content/keycloak/testsuite/integration-arquillian/test-apps/photoz/photoz-restful-api/src/main/webapp]
# [INFO] Webapp assembled in [36 msecs]
# [INFO] Building war: /content/keycloak/testsuite/integration-arquillian/test-apps/photoz/photoz-restful-api/target/photoz-restful-api.war
# [INFO] Packaging classes
# [INFO] Building jar: /content/keycloak/testsuite/integration-arquillian/test-apps/photoz/photoz-restful-api/target/photoz-restful-api-classes.jar
# [INFO]
# [INFO] --- maven-source-plugin:3.1.0:jar-no-fork (attach-sources) @ photoz-restful-api ---
# [INFO] Building jar: /content/keycloak/testsuite/integration-arquillian/test-apps/photoz/photoz-restful-api/target/photoz-restful-api-sources.jar
# [INFO]
# [INFO] --- maven-install-plugin:2.5.2:install (default-install) @ photoz-restful-api ---
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/test-apps/photoz/photoz-restful-api/target/photoz-restful-api.war to /root/.m2/repository/org/keycloak/testsuite/photoz-restful-api/14.0.0-SNAPSHOT/photoz-restful-api-14.0.0-SNAPSHOT.war
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/test-apps/photoz/photoz-restful-api/pom.xml to /root/.m2/repository/org/keycloak/testsuite/photoz-restful-api/14.0.0-SNAPSHOT/photoz-restful-api-14.0.0-SNAPSHOT.pom
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/test-apps/photoz/photoz-restful-api/target/photoz-restful-api-classes.jar to /root/.m2/repository/org/keycloak/testsuite/photoz-restful-api/14.0.0-SNAPSHOT/photoz-restful-api-14.0.0-SNAPSHOT-classes.jar
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/test-apps/photoz/photoz-restful-api/target/photoz-restful-api-sources.jar to /root/.m2/repository/org/keycloak/testsuite/photoz-restful-api/14.0.0-SNAPSHOT/photoz-restful-api-14.0.0-SNAPSHOT-sources.jar
# [INFO]
# [INFO] -------------< org.keycloak.testsuite:photoz-html5-client >-------------
# [INFO] Building Keycloak Authz Tests: Photoz HTML5 Client 14.0.0-SNAPSHOT [6/52]
# [INFO] --------------------------------[ war ]---------------------------------
# [INFO]
# [INFO] --- maven-clean-plugin:3.1.0:clean (default-clean) @ photoz-html5-client ---
# [INFO] Deleting /content/keycloak/testsuite/integration-arquillian/test-apps/photoz/photoz-html5-client/target
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-java-version) @ photoz-html5-client ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven-version) @ photoz-html5-client ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven) @ photoz-html5-client ---
# [INFO]
# [INFO] --- buildnumber-maven-plugin:1.4:create (get-scm-revision) @ photoz-html5-client ---
# [INFO]
# [INFO] --- maven-resources-plugin:3.0.1:resources (default-resources) @ photoz-html5-client ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /content/keycloak/testsuite/integration-arquillian/test-apps/photoz/photoz-html5-client/src/main/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.8.1-jboss-1:compile (default-compile) @ photoz-html5-client ---
# [INFO] No sources to compile
# [INFO]
# [INFO] --- maven-resources-plugin:3.0.1:testResources (default-testResources) @ photoz-html5-client ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /content/keycloak/testsuite/integration-arquillian/test-apps/photoz/photoz-html5-client/src/test/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.8.1-jboss-1:testCompile (default-testCompile) @ photoz-html5-client ---
# [INFO] No sources to compile
# [INFO]
# [INFO] --- maven-surefire-plugin:2.22.2:test (default-test) @ photoz-html5-client ---
# [INFO] No tests to run.
# [INFO]
# [INFO] --- maven-war-plugin:3.2.3:war (default-war) @ photoz-html5-client ---
# [INFO] Packaging webapp
# [INFO] Assembling webapp [photoz-html5-client] in [/content/keycloak/testsuite/integration-arquillian/test-apps/photoz/photoz-html5-client/target/photoz-html5-client]
# [INFO] Processing war project
# [INFO] Copying webapp resources [/content/keycloak/testsuite/integration-arquillian/test-apps/photoz/photoz-html5-client/src/main/webapp]
# [INFO] Webapp assembled in [20 msecs]
# [INFO] Building war: /content/keycloak/testsuite/integration-arquillian/test-apps/photoz/photoz-html5-client/target/photoz-html5-client.war
# [INFO]
# [INFO] --- maven-source-plugin:3.1.0:jar-no-fork (attach-sources) @ photoz-html5-client ---
# [INFO] No sources in project. Archive not created.
# [INFO]
# [INFO] --- maven-install-plugin:2.5.2:install (default-install) @ photoz-html5-client ---
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/test-apps/photoz/photoz-html5-client/target/photoz-html5-client.war to /root/.m2/repository/org/keycloak/testsuite/photoz-html5-client/14.0.0-SNAPSHOT/photoz-html5-client-14.0.0-SNAPSHOT.war
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/test-apps/photoz/photoz-html5-client/pom.xml to /root/.m2/repository/org/keycloak/testsuite/photoz-html5-client/14.0.0-SNAPSHOT/photoz-html5-client-14.0.0-SNAPSHOT.pom
# [INFO]
# [INFO] ----------< org.keycloak.testsuite:hello-world-authz-service >----------
# [INFO] Building Keycloak Authz Tests: Hello World Example 14.0.0-SNAPSHOT [7/52]
# [INFO] --------------------------------[ war ]---------------------------------
# [INFO]
# [INFO] --- maven-clean-plugin:3.1.0:clean (default-clean) @ hello-world-authz-service ---
# [INFO] Deleting /content/keycloak/testsuite/integration-arquillian/test-apps/hello-world-authz-service/target
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-java-version) @ hello-world-authz-service ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven-version) @ hello-world-authz-service ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven) @ hello-world-authz-service ---
# [INFO]
# [INFO] --- buildnumber-maven-plugin:1.4:create (get-scm-revision) @ hello-world-authz-service ---
# [INFO]
# [INFO] --- maven-resources-plugin:3.0.1:resources (default-resources) @ hello-world-authz-service ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /content/keycloak/testsuite/integration-arquillian/test-apps/hello-world-authz-service/src/main/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.8.1-jboss-1:compile (default-compile) @ hello-world-authz-service ---
# [INFO] No sources to compile
# [INFO]
# [INFO] --- maven-resources-plugin:3.0.1:testResources (default-testResources) @ hello-world-authz-service ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /content/keycloak/testsuite/integration-arquillian/test-apps/hello-world-authz-service/src/test/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.8.1-jboss-1:testCompile (default-testCompile) @ hello-world-authz-service ---
# [INFO] No sources to compile
# [INFO]
# [INFO] --- maven-surefire-plugin:2.22.2:test (default-test) @ hello-world-authz-service ---
# [INFO] No tests to run.
# [INFO]
# [INFO] --- maven-war-plugin:3.2.3:war (default-war) @ hello-world-authz-service ---
# [INFO] Packaging webapp
# [INFO] Assembling webapp [hello-world-authz-service] in [/content/keycloak/testsuite/integration-arquillian/test-apps/hello-world-authz-service/target/hello-world-authz-service-14.0.0-SNAPSHOT]
# [INFO] Processing war project
# [INFO] Copying webapp resources [/content/keycloak/testsuite/integration-arquillian/test-apps/hello-world-authz-service/src/main/webapp]
# [INFO] Webapp assembled in [3 msecs]
# [INFO] Building war: /content/keycloak/testsuite/integration-arquillian/test-apps/hello-world-authz-service/target/hello-world-authz-service-14.0.0-SNAPSHOT.war
# [INFO]
# [INFO] --- maven-source-plugin:3.1.0:jar-no-fork (attach-sources) @ hello-world-authz-service ---
# [INFO] No sources in project. Archive not created.
# [INFO]
# [INFO] --- maven-install-plugin:2.5.2:install (default-install) @ hello-world-authz-service ---
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/test-apps/hello-world-authz-service/target/hello-world-authz-service-14.0.0-SNAPSHOT.war to /root/.m2/repository/org/keycloak/testsuite/hello-world-authz-service/14.0.0-SNAPSHOT/hello-world-authz-service-14.0.0-SNAPSHOT.war
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/test-apps/hello-world-authz-service/pom.xml to /root/.m2/repository/org/keycloak/testsuite/hello-world-authz-service/14.0.0-SNAPSHOT/hello-world-authz-service-14.0.0-SNAPSHOT.pom
# [INFO]
# [INFO] --------------< org.keycloak.testsuite:servlet-authz-app >--------------
# [INFO] Building Keycloak Authz: Servlet Authorization Test 14.0.0-SNAPSHOT [8/52]
# [INFO] --------------------------------[ war ]---------------------------------
# [INFO]
# [INFO] --- maven-clean-plugin:3.1.0:clean (default-clean) @ servlet-authz-app ---
# [INFO] Deleting /content/keycloak/testsuite/integration-arquillian/test-apps/servlet-authz/target
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-java-version) @ servlet-authz-app ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven-version) @ servlet-authz-app ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven) @ servlet-authz-app ---
# [INFO]
# [INFO] --- buildnumber-maven-plugin:1.4:create (get-scm-revision) @ servlet-authz-app ---
# [INFO]
# [INFO] --- maven-resources-plugin:3.0.1:resources (default-resources) @ servlet-authz-app ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /content/keycloak/testsuite/integration-arquillian/test-apps/servlet-authz/src/main/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.8.1-jboss-1:compile (default-compile) @ servlet-authz-app ---
# [INFO] Changes detected - recompiling the module!
# [INFO] Compiling 1 source file to /content/keycloak/testsuite/integration-arquillian/test-apps/servlet-authz/target/classes
# [WARNING] bootstrap class path not set in conjunction with -source 7
# [INFO]
# [INFO] --- maven-resources-plugin:3.0.1:testResources (default-testResources) @ servlet-authz-app ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /content/keycloak/testsuite/integration-arquillian/test-apps/servlet-authz/src/test/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.8.1-jboss-1:testCompile (default-testCompile) @ servlet-authz-app ---
# [INFO] No sources to compile
# [INFO]
# [INFO] --- maven-surefire-plugin:2.22.2:test (default-test) @ servlet-authz-app ---
# [INFO] No tests to run.
# [INFO]
# [INFO] --- maven-war-plugin:3.2.3:war (default-war) @ servlet-authz-app ---
# [INFO] Packaging webapp
# [INFO] Assembling webapp [servlet-authz-app] in [/content/keycloak/testsuite/integration-arquillian/test-apps/servlet-authz/target/servlet-authz-app]
# [INFO] Processing war project
# [INFO] Copying webapp resources [/content/keycloak/testsuite/integration-arquillian/test-apps/servlet-authz/src/main/webapp]
# [INFO] Webapp assembled in [39 msecs]
# [INFO] Building war: /content/keycloak/testsuite/integration-arquillian/test-apps/servlet-authz/target/servlet-authz-app.war
# [INFO]
# [INFO] --- maven-source-plugin:3.1.0:jar-no-fork (attach-sources) @ servlet-authz-app ---
# [INFO] Building jar: /content/keycloak/testsuite/integration-arquillian/test-apps/servlet-authz/target/servlet-authz-app-sources.jar
# [INFO]
# [INFO] --- maven-install-plugin:2.5.2:install (default-install) @ servlet-authz-app ---
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/test-apps/servlet-authz/target/servlet-authz-app.war to /root/.m2/repository/org/keycloak/testsuite/servlet-authz-app/14.0.0-SNAPSHOT/servlet-authz-app-14.0.0-SNAPSHOT.war
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/test-apps/servlet-authz/pom.xml to /root/.m2/repository/org/keycloak/testsuite/servlet-authz-app/14.0.0-SNAPSHOT/servlet-authz-app-14.0.0-SNAPSHOT.pom
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/test-apps/servlet-authz/target/servlet-authz-app-sources.jar to /root/.m2/repository/org/keycloak/testsuite/servlet-authz-app/14.0.0-SNAPSHOT/servlet-authz-app-14.0.0-SNAPSHOT-sources.jar
# [INFO]
# [INFO] -----------< org.keycloak.testsuite:servlet-policy-enforcer >-----------
# [INFO] Building Keycloak Authz: Simple Servlet App with Policy Enforcer 14.0.0-SNAPSHOT [9/52]
# [INFO] --------------------------------[ war ]---------------------------------
# [INFO]
# [INFO] --- maven-clean-plugin:3.1.0:clean (default-clean) @ servlet-policy-enforcer ---
# [INFO] Deleting /content/keycloak/testsuite/integration-arquillian/test-apps/servlet-policy-enforcer/target
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-java-version) @ servlet-policy-enforcer ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven-version) @ servlet-policy-enforcer ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven) @ servlet-policy-enforcer ---
# [INFO]
# [INFO] --- buildnumber-maven-plugin:1.4:create (get-scm-revision) @ servlet-policy-enforcer ---
# [INFO]
# [INFO] --- maven-resources-plugin:3.0.1:resources (default-resources) @ servlet-policy-enforcer ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /content/keycloak/testsuite/integration-arquillian/test-apps/servlet-policy-enforcer/src/main/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.8.1-jboss-1:compile (default-compile) @ servlet-policy-enforcer ---
# [INFO] No sources to compile
# [INFO]
# [INFO] --- maven-resources-plugin:3.0.1:testResources (default-testResources) @ servlet-policy-enforcer ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /content/keycloak/testsuite/integration-arquillian/test-apps/servlet-policy-enforcer/src/test/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.8.1-jboss-1:testCompile (default-testCompile) @ servlet-policy-enforcer ---
# [INFO] No sources to compile
# [INFO]
# [INFO] --- maven-surefire-plugin:2.22.2:test (default-test) @ servlet-policy-enforcer ---
# [INFO] No tests to run.
# [INFO]
# [INFO] --- maven-war-plugin:3.2.3:war (default-war) @ servlet-policy-enforcer ---
# [INFO] Packaging webapp
# [INFO] Assembling webapp [servlet-policy-enforcer] in [/content/keycloak/testsuite/integration-arquillian/test-apps/servlet-policy-enforcer/target/servlet-policy-enforcer-14.0.0-SNAPSHOT]
# [INFO] Processing war project
# [INFO] Copying webapp resources [/content/keycloak/testsuite/integration-arquillian/test-apps/servlet-policy-enforcer/src/main/webapp]
# [INFO] Webapp assembled in [3 msecs]
# [INFO] Building war: /content/keycloak/testsuite/integration-arquillian/test-apps/servlet-policy-enforcer/target/servlet-policy-enforcer-14.0.0-SNAPSHOT.war
# [INFO]
# [INFO] --- maven-source-plugin:3.1.0:jar-no-fork (attach-sources) @ servlet-policy-enforcer ---
# [INFO] No sources in project. Archive not created.
# [INFO]
# [INFO] --- maven-install-plugin:2.5.2:install (default-install) @ servlet-policy-enforcer ---
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/test-apps/servlet-policy-enforcer/target/servlet-policy-enforcer-14.0.0-SNAPSHOT.war to /root/.m2/repository/org/keycloak/testsuite/servlet-policy-enforcer/14.0.0-SNAPSHOT/servlet-policy-enforcer-14.0.0-SNAPSHOT.war
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/test-apps/servlet-policy-enforcer/pom.xml to /root/.m2/repository/org/keycloak/testsuite/servlet-policy-enforcer/14.0.0-SNAPSHOT/servlet-policy-enforcer-14.0.0-SNAPSHOT.pom
# [INFO]
# [INFO] --< org.keycloak.testsuite:integration-arquillian-test-apps-servlets >--
# [INFO] Building integration-arquillian-test-apps-servlets 14.0.0-SNAPSHOT [10/52]
# [INFO] --------------------------------[ jar ]---------------------------------
# [INFO]
# [INFO] --- maven-clean-plugin:3.1.0:clean (default-clean) @ integration-arquillian-test-apps-servlets ---
# [INFO] Deleting /content/keycloak/testsuite/integration-arquillian/test-apps/servlets/target
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-java-version) @ integration-arquillian-test-apps-servlets ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven-version) @ integration-arquillian-test-apps-servlets ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven) @ integration-arquillian-test-apps-servlets ---
# [INFO]
# [INFO] --- buildnumber-maven-plugin:1.4:create (get-scm-revision) @ integration-arquillian-test-apps-servlets ---
# [INFO]
# [INFO] --- maven-resources-plugin:3.0.1:resources (default-resources) @ integration-arquillian-test-apps-servlets ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /content/keycloak/testsuite/integration-arquillian/test-apps/servlets/src/main/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.8.1-jboss-1:compile (default-compile) @ integration-arquillian-test-apps-servlets ---
# [INFO] Changes detected - recompiling the module!
# [INFO] Compiling 23 source files to /content/keycloak/testsuite/integration-arquillian/test-apps/servlets/target/classes
# [WARNING] bootstrap class path not set in conjunction with -source 7
# [WARNING] /content/keycloak/testsuite/integration-arquillian/test-apps/servlets/src/main/java/org/keycloak/testsuite/adapter/servlet/KerberosCredDelegServlet.java:[93,16] unchecked call to put(K,V) as a member of the raw type java.util.Hashtable
# [WARNING] /content/keycloak/testsuite/integration-arquillian/test-apps/servlets/src/main/java/org/keycloak/testsuite/adapter/servlet/KerberosCredDelegServlet.java:[94,16] unchecked call to put(K,V) as a member of the raw type java.util.Hashtable
# [WARNING] /content/keycloak/testsuite/integration-arquillian/test-apps/servlets/src/main/java/org/keycloak/testsuite/adapter/servlet/KerberosCredDelegServlet.java:[97,20] unchecked call to put(K,V) as a member of the raw type java.util.Hashtable
# [WARNING] /content/keycloak/testsuite/integration-arquillian/test-apps/servlets/src/main/java/org/keycloak/testsuite/adapter/servlet/KerberosCredDelegServlet.java:[98,20] unchecked call to put(K,V) as a member of the raw type java.util.Hashtable
# [INFO]
# [INFO] --- maven-resources-plugin:3.0.1:testResources (default-testResources) @ integration-arquillian-test-apps-servlets ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /content/keycloak/testsuite/integration-arquillian/test-apps/servlets/src/test/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.8.1-jboss-1:testCompile (default-testCompile) @ integration-arquillian-test-apps-servlets ---
# [INFO] No sources to compile
# [INFO]
# [INFO] --- maven-surefire-plugin:2.22.2:test (default-test) @ integration-arquillian-test-apps-servlets ---
# [INFO] No tests to run.
# [INFO]
# [INFO] --- maven-jar-plugin:3.1.2:jar (default-jar) @ integration-arquillian-test-apps-servlets ---
# [INFO] Building jar: /content/keycloak/testsuite/integration-arquillian/test-apps/servlets/target/integration-arquillian-test-apps-servlets-14.0.0-SNAPSHOT.jar
# [INFO]
# [INFO] --- maven-source-plugin:3.1.0:jar-no-fork (attach-sources) @ integration-arquillian-test-apps-servlets ---
# [INFO] Building jar: /content/keycloak/testsuite/integration-arquillian/test-apps/servlets/target/integration-arquillian-test-apps-servlets-14.0.0-SNAPSHOT-sources.jar
# [INFO]
# [INFO] --- maven-install-plugin:2.5.2:install (default-install) @ integration-arquillian-test-apps-servlets ---
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/test-apps/servlets/target/integration-arquillian-test-apps-servlets-14.0.0-SNAPSHOT.jar to /root/.m2/repository/org/keycloak/testsuite/integration-arquillian-test-apps-servlets/14.0.0-SNAPSHOT/integration-arquillian-test-apps-servlets-14.0.0-SNAPSHOT.jar
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/test-apps/servlets/pom.xml to /root/.m2/repository/org/keycloak/testsuite/integration-arquillian-test-apps-servlets/14.0.0-SNAPSHOT/integration-arquillian-test-apps-servlets-14.0.0-SNAPSHOT.pom
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/test-apps/servlets/target/integration-arquillian-test-apps-servlets-14.0.0-SNAPSHOT-sources.jar to /root/.m2/repository/org/keycloak/testsuite/integration-arquillian-test-apps-servlets/14.0.0-SNAPSHOT/integration-arquillian-test-apps-servlets-14.0.0-SNAPSHOT-sources.jar
# [INFO]
# [INFO] --------< org.keycloak.testsuite:keycloak-test-app-profile-jee >--------
# [INFO] Building Keycloak Test App Profile JEE 14.0.0-SNAPSHOT           [11/52]
# [INFO] --------------------------------[ war ]---------------------------------
# [INFO]
# [INFO] --- maven-clean-plugin:3.1.0:clean (default-clean) @ keycloak-test-app-profile-jee ---
# [INFO] Deleting /content/keycloak/testsuite/integration-arquillian/test-apps/app-profile-jee/target
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-java-version) @ keycloak-test-app-profile-jee ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven-version) @ keycloak-test-app-profile-jee ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven) @ keycloak-test-app-profile-jee ---
# [INFO]
# [INFO] --- buildnumber-maven-plugin:1.4:create (get-scm-revision) @ keycloak-test-app-profile-jee ---
# [INFO]
# [INFO] --- maven-resources-plugin:3.0.1:resources (default-resources) @ keycloak-test-app-profile-jee ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /content/keycloak/testsuite/integration-arquillian/test-apps/app-profile-jee/src/main/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.8.1-jboss-1:compile (default-compile) @ keycloak-test-app-profile-jee ---
# [INFO] Changes detected - recompiling the module!
# [INFO] Compiling 1 source file to /content/keycloak/testsuite/integration-arquillian/test-apps/app-profile-jee/target/classes
# [WARNING] bootstrap class path not set in conjunction with -source 7
# [INFO]
# [INFO] --- maven-resources-plugin:3.0.1:testResources (default-testResources) @ keycloak-test-app-profile-jee ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /content/keycloak/testsuite/integration-arquillian/test-apps/app-profile-jee/src/test/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.8.1-jboss-1:testCompile (default-testCompile) @ keycloak-test-app-profile-jee ---
# [INFO] No sources to compile
# [INFO]
# [INFO] --- maven-surefire-plugin:2.22.2:test (default-test) @ keycloak-test-app-profile-jee ---
# [INFO] No tests to run.
# [INFO]
# [INFO] --- maven-war-plugin:3.2.3:war (default-war) @ keycloak-test-app-profile-jee ---
# [INFO] Packaging webapp
# [INFO] Assembling webapp [keycloak-test-app-profile-jee] in [/content/keycloak/testsuite/integration-arquillian/test-apps/app-profile-jee/target/app-profile-jee]
# [INFO] Processing war project
# [INFO] Copying webapp resources [/content/keycloak/testsuite/integration-arquillian/test-apps/app-profile-jee/src/main/webapp]
# [INFO] Webapp assembled in [12 msecs]
# [INFO] Building war: /content/keycloak/testsuite/integration-arquillian/test-apps/app-profile-jee/target/app-profile-jee.war
# [INFO]
# [INFO] --- maven-source-plugin:3.1.0:jar-no-fork (attach-sources) @ keycloak-test-app-profile-jee ---
# [INFO] Building jar: /content/keycloak/testsuite/integration-arquillian/test-apps/app-profile-jee/target/app-profile-jee-sources.jar
# [INFO]
# [INFO] --- maven-install-plugin:2.5.2:install (default-install) @ keycloak-test-app-profile-jee ---
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/test-apps/app-profile-jee/target/app-profile-jee.war to /root/.m2/repository/org/keycloak/testsuite/keycloak-test-app-profile-jee/14.0.0-SNAPSHOT/keycloak-test-app-profile-jee-14.0.0-SNAPSHOT.war
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/test-apps/app-profile-jee/pom.xml to /root/.m2/repository/org/keycloak/testsuite/keycloak-test-app-profile-jee/14.0.0-SNAPSHOT/keycloak-test-app-profile-jee-14.0.0-SNAPSHOT.pom
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/test-apps/app-profile-jee/target/app-profile-jee-sources.jar to /root/.m2/repository/org/keycloak/testsuite/keycloak-test-app-profile-jee/14.0.0-SNAPSHOT/keycloak-test-app-profile-jee-14.0.0-SNAPSHOT-sources.jar
# [INFO]
# [INFO] --< org.keycloak.testsuite:integration-arquillian-test-apps-cors-parent >--
# [INFO] Building integration-arquillian-test-apps-cors-parent 14.0.0-SNAPSHOT [12/52]
# [INFO] --------------------------------[ pom ]---------------------------------
# [INFO]
# [INFO] --- maven-clean-plugin:3.1.0:clean (default-clean) @ integration-arquillian-test-apps-cors-parent ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-java-version) @ integration-arquillian-test-apps-cors-parent ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven-version) @ integration-arquillian-test-apps-cors-parent ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven) @ integration-arquillian-test-apps-cors-parent ---
# [INFO]
# [INFO] --- buildnumber-maven-plugin:1.4:create (get-scm-revision) @ integration-arquillian-test-apps-cors-parent ---
# [INFO]
# [INFO] --- maven-source-plugin:3.1.0:jar-no-fork (attach-sources) @ integration-arquillian-test-apps-cors-parent ---
# [INFO]
# [INFO] --- maven-install-plugin:2.5.2:install (default-install) @ integration-arquillian-test-apps-cors-parent ---
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/test-apps/cors/pom.xml to /root/.m2/repository/org/keycloak/testsuite/integration-arquillian-test-apps-cors-parent/14.0.0-SNAPSHOT/integration-arquillian-test-apps-cors-parent-14.0.0-SNAPSHOT.pom
# [INFO]
# [INFO] --< org.keycloak.testsuite:integration-arquillian-test-apps-cors-angular-product >--
# [INFO] Building Angular Product Portal JS 14.0.0-SNAPSHOT               [13/52]
# [INFO] --------------------------------[ war ]---------------------------------
# [INFO]
# [INFO] --- maven-clean-plugin:3.1.0:clean (default-clean) @ integration-arquillian-test-apps-cors-angular-product ---
# [INFO] Deleting /content/keycloak/testsuite/integration-arquillian/test-apps/cors/angular-product/target
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-java-version) @ integration-arquillian-test-apps-cors-angular-product ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven-version) @ integration-arquillian-test-apps-cors-angular-product ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven) @ integration-arquillian-test-apps-cors-angular-product ---
# [INFO]
# [INFO] --- buildnumber-maven-plugin:1.4:create (get-scm-revision) @ integration-arquillian-test-apps-cors-angular-product ---
# [INFO]
# [INFO] --- maven-dependency-plugin:3.1.1:unpack (unpack-javascript-adapter) @ integration-arquillian-test-apps-cors-angular-product ---
# [INFO] Configured Artifact: org.keycloak:keycloak-js-adapter:14.0.0-SNAPSHOT:jar
# [INFO] Unpacking /root/.m2/repository/org/keycloak/keycloak-js-adapter/14.0.0-SNAPSHOT/keycloak-js-adapter-14.0.0-SNAPSHOT.jar to /content/keycloak/testsuite/integration-arquillian/test-apps/cors/angular-product/target/angular-cors-product/js with includes "**/keycloak.js" and excludes ""
# [INFO]
# [INFO] --- maven-resources-plugin:3.0.1:resources (default-resources) @ integration-arquillian-test-apps-cors-angular-product ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /content/keycloak/testsuite/integration-arquillian/test-apps/cors/angular-product/src/main/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.8.1-jboss-1:compile (default-compile) @ integration-arquillian-test-apps-cors-angular-product ---
# [INFO] No sources to compile
# [INFO]
# [INFO] --- maven-resources-plugin:3.0.1:testResources (default-testResources) @ integration-arquillian-test-apps-cors-angular-product ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /content/keycloak/testsuite/integration-arquillian/test-apps/cors/angular-product/src/test/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.8.1-jboss-1:testCompile (default-testCompile) @ integration-arquillian-test-apps-cors-angular-product ---
# [INFO] No sources to compile
# [INFO]
# [INFO] --- maven-surefire-plugin:2.22.2:test (default-test) @ integration-arquillian-test-apps-cors-angular-product ---
# [INFO] No tests to run.
# [INFO]
# [INFO] --- maven-war-plugin:3.2.3:war (default-war) @ integration-arquillian-test-apps-cors-angular-product ---
# [INFO] Packaging webapp
# [INFO] Assembling webapp [integration-arquillian-test-apps-cors-angular-product] in [/content/keycloak/testsuite/integration-arquillian/test-apps/cors/angular-product/target/angular-cors-product]
# [INFO] Processing war project
# [INFO] Copying webapp resources [/content/keycloak/testsuite/integration-arquillian/test-apps/cors/angular-product/src/main/webapp]
# [INFO] Webapp assembled in [12 msecs]
# [INFO] Building war: /content/keycloak/testsuite/integration-arquillian/test-apps/cors/angular-product/target/angular-cors-product.war
# [INFO]
# [INFO] --- maven-source-plugin:3.1.0:jar-no-fork (attach-sources) @ integration-arquillian-test-apps-cors-angular-product ---
# [INFO] No sources in project. Archive not created.
# [INFO]
# [INFO] --- maven-install-plugin:2.5.2:install (default-install) @ integration-arquillian-test-apps-cors-angular-product ---
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/test-apps/cors/angular-product/target/angular-cors-product.war to /root/.m2/repository/org/keycloak/testsuite/integration-arquillian-test-apps-cors-angular-product/14.0.0-SNAPSHOT/integration-arquillian-test-apps-cors-angular-product-14.0.0-SNAPSHOT.war
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/test-apps/cors/angular-product/pom.xml to /root/.m2/repository/org/keycloak/testsuite/integration-arquillian-test-apps-cors-angular-product/14.0.0-SNAPSHOT/integration-arquillian-test-apps-cors-angular-product-14.0.0-SNAPSHOT.pom
# [INFO]
# [INFO] --< org.keycloak.testsuite:integration-arquillian-test-apps-cors-database-service >--
# [INFO] Building JAX-RS Database Service Using OAuth Bearer Tokens 14.0.0-SNAPSHOT [14/52]
# [INFO] --------------------------------[ war ]---------------------------------
# [INFO]
# [INFO] --- maven-clean-plugin:3.1.0:clean (default-clean) @ integration-arquillian-test-apps-cors-database-service ---
# [INFO] Deleting /content/keycloak/testsuite/integration-arquillian/test-apps/cors/database-service/target
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-java-version) @ integration-arquillian-test-apps-cors-database-service ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven-version) @ integration-arquillian-test-apps-cors-database-service ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven) @ integration-arquillian-test-apps-cors-database-service ---
# [INFO]
# [INFO] --- buildnumber-maven-plugin:1.4:create (get-scm-revision) @ integration-arquillian-test-apps-cors-database-service ---
# [INFO]
# [INFO] --- maven-resources-plugin:3.0.1:resources (default-resources) @ integration-arquillian-test-apps-cors-database-service ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /content/keycloak/testsuite/integration-arquillian/test-apps/cors/database-service/src/main/resources
# [INFO]
# ...
# [INFO]
# [INFO] --- maven-source-plugin:3.1.0:jar-no-fork (attach-sources) @ integration-arquillian-tests-adapters-was ---
# [INFO]
# [INFO] --- maven-install-plugin:2.5.2:install (default-install) @ integration-arquillian-tests-adapters-was ---
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/tests/other/adapters/was/pom.xml to /root/.m2/repository/org/keycloak/testsuite/integration-arquillian-tests-adapters-was/14.0.0-SNAPSHOT/integration-arquillian-tests-adapters-was-14.0.0-SNAPSHOT.pom
# [INFO]
# [INFO] --< org.keycloak.testsuite:integration-arquillian-tests-adapters-wls >--
# [INFO] Building Adapter Tests - WLS 14.0.0-SNAPSHOT                     [51/52]
# [INFO] --------------------------------[ pom ]---------------------------------
# [INFO]
# [INFO] --- maven-clean-plugin:3.1.0:clean (default-clean) @ integration-arquillian-tests-adapters-wls ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-java-version) @ integration-arquillian-tests-adapters-wls ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven-version) @ integration-arquillian-tests-adapters-wls ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven) @ integration-arquillian-tests-adapters-wls ---
# [INFO]
# [INFO] --- buildnumber-maven-plugin:1.4:create (get-scm-revision) @ integration-arquillian-tests-adapters-wls ---
# [INFO]
# [INFO] --- shrinkwrap-resolver-maven-plugin:3.1.4:propagate-execution-context (default) @ integration-arquillian-tests-adapters-wls ---
# [INFO]
# [INFO] --- maven-source-plugin:3.1.0:jar-no-fork (attach-sources) @ integration-arquillian-tests-adapters-wls ---
# [INFO]
# [INFO] --- maven-install-plugin:2.5.2:install (default-install) @ integration-arquillian-tests-adapters-wls ---
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/tests/other/adapters/wls/pom.xml to /root/.m2/repository/org/keycloak/testsuite/integration-arquillian-tests-adapters-wls/14.0.0-SNAPSHOT/integration-arquillian-tests-adapters-wls-14.0.0-SNAPSHOT.pom
# [INFO]
# [INFO] ------< org.keycloak.testsuite:integration-arquillian-tests-sssd >------
# [INFO] Building SSSD tests 14.0.0-SNAPSHOT                              [52/52]
# [INFO] --------------------------------[ jar ]---------------------------------
# [INFO]
# [INFO] --- maven-clean-plugin:3.1.0:clean (default-clean) @ integration-arquillian-tests-sssd ---
# [INFO] Deleting /content/keycloak/testsuite/integration-arquillian/tests/other/sssd/target
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-java-version) @ integration-arquillian-tests-sssd ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven-version) @ integration-arquillian-tests-sssd ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven) @ integration-arquillian-tests-sssd ---
# [INFO]
# [INFO] --- buildnumber-maven-plugin:1.4:create (get-scm-revision) @ integration-arquillian-tests-sssd ---
# [INFO]
# [INFO] --- maven-dependency-plugin:3.1.1:unpack (unpack-auth-server-jboss) @ integration-arquillian-tests-sssd ---
# [INFO] Skipping plugin execution
# [INFO]
# [INFO] --- maven-dependency-plugin:3.1.1:unpack (unpack-test-resources) @ integration-arquillian-tests-sssd ---
# [INFO] Configured Artifact: org.keycloak.testsuite:integration-arquillian-tests-base:tests:14.0.0-SNAPSHOT:jar
# [INFO] Unpacking /content/keycloak/testsuite/integration-arquillian/tests/base/target/integration-arquillian-tests-base-14.0.0-SNAPSHOT-tests.jar to /content/keycloak/testsuite/integration-arquillian/tests/other/sssd/target/dependency with includes "arquillian.xml,wildfly-config.xml,keycloak-add-user.json,test-constants.properties,kerberos/*,keystore/*,password-blacklists/*,log4j.properties,vault/*" and excludes ""
# [INFO]
# [INFO] --- maven-resources-plugin:3.0.1:copy-resources (copy-truststore) @ integration-arquillian-tests-sssd ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /content/keycloak/testsuite/integration-arquillian/tests/other/sssd/src/test/resources
# [INFO]
# [INFO] --- maven-resources-plugin:3.0.1:resources (default-resources) @ integration-arquillian-tests-sssd ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /content/keycloak/testsuite/integration-arquillian/tests/other/sssd/src/main/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.8.1-jboss-1:compile (default-compile) @ integration-arquillian-tests-sssd ---
# [INFO] No sources to compile
# [INFO]
# [INFO] --- maven-dependency-plugin:3.1.1:unpack (unpack-undertow-server) @ integration-arquillian-tests-sssd ---
# [INFO] Configured Artifact: org.keycloak.testsuite:integration-arquillian-servers-auth-server-undertow:14.0.0-SNAPSHOT:jar
# [INFO] Unpacking /content/keycloak/testsuite/integration-arquillian/servers/auth-server/undertow/target/integration-arquillian-servers-auth-server-undertow-14.0.0-SNAPSHOT.jar to /content/keycloak/testsuite/integration-arquillian/tests/other/sssd/target/containers/auth-server-undertow with includes "*.jks,*.crt,*.truststore,*.crl,*.key,certs/clients/*" and excludes ""
# [INFO]
# [INFO] --- maven-dependency-plugin:3.1.1:unpack (unpack-quarkus-server) @ integration-arquillian-tests-sssd ---
# [INFO] Skipping plugin execution
# [INFO]
# [INFO] --- maven-dependency-plugin:3.1.1:unpack (unpack-app-server) @ integration-arquillian-tests-sssd ---
# [INFO] Skipping plugin execution
# [INFO]
# [INFO] --- maven-dependency-plugin:3.1.1:copy (example-wars) @ integration-arquillian-tests-sssd ---
# [INFO] Configured Artifact: org.keycloak.testsuite:hello-world-authz-service:14.0.0-SNAPSHOT:war
# [INFO] Configured Artifact: org.keycloak.testsuite:photoz-html5-client:14.0.0-SNAPSHOT:war
# [INFO] Configured Artifact: org.keycloak.testsuite:photoz-restful-api:14.0.0-SNAPSHOT:war
# [INFO] Configured Artifact: org.keycloak.testsuite:servlet-authz-app:14.0.0-SNAPSHOT:war
# [INFO] Configured Artifact: org.keycloak.testsuite:servlet-policy-enforcer:14.0.0-SNAPSHOT:war
# [INFO] Configured Artifact: org.keycloak.testsuite:integration-arquillian-test-apps-cors-angular-product:14.0.0-SNAPSHOT:war
# [INFO] Configured Artifact: org.keycloak.testsuite:integration-arquillian-test-apps-cors-database-service:14.0.0-SNAPSHOT:war
# [INFO] Copying hello-world-authz-service-14.0.0-SNAPSHOT.war to /content/keycloak/testsuite/integration-arquillian/tests/other/sssd/target/examples/hello-world-authz-service-14.0.0-SNAPSHOT.war
# [INFO] Copying photoz-html5-client.war to /content/keycloak/testsuite/integration-arquillian/tests/other/sssd/target/examples/photoz-html5-client-14.0.0-SNAPSHOT.war
# [INFO] Copying photoz-restful-api.war to /content/keycloak/testsuite/integration-arquillian/tests/other/sssd/target/examples/photoz-restful-api-14.0.0-SNAPSHOT.war
# [INFO] Copying servlet-authz-app.war to /content/keycloak/testsuite/integration-arquillian/tests/other/sssd/target/examples/servlet-authz-app-14.0.0-SNAPSHOT.war
# [INFO] Copying servlet-policy-enforcer-14.0.0-SNAPSHOT.war to /content/keycloak/testsuite/integration-arquillian/tests/other/sssd/target/examples/servlet-policy-enforcer-14.0.0-SNAPSHOT.war
# [INFO] Copying angular-cors-product.war to /content/keycloak/testsuite/integration-arquillian/tests/other/sssd/target/examples/integration-arquillian-test-apps-cors-angular-product-14.0.0-SNAPSHOT.war
# [INFO] Copying cors-database.war to /content/keycloak/testsuite/integration-arquillian/tests/other/sssd/target/examples/integration-arquillian-test-apps-cors-database-service-14.0.0-SNAPSHOT.war
# [INFO]
# [INFO] --- maven-dependency-plugin:3.1.1:unpack (test-apps-realms) @ integration-arquillian-tests-sssd ---
# [INFO] Configured Artifact: org.keycloak.testsuite:integration-arquillian-test-apps-dist:14.0.0-SNAPSHOT:zip
# [INFO] Unpacking /content/keycloak/testsuite/integration-arquillian/test-apps/test-apps-dist/target/test-apps-dist.zip to /content/keycloak/testsuite/integration-arquillian/tests/other/sssd/target/examples with includes "**/*realm.json,**/*authz-service.json,**/testsaml.json,**/*-keycloak.json" and excludes ""
# [INFO]
# [INFO] --- maven-resources-plugin:3.0.1:copy-resources (example-realms) @ integration-arquillian-tests-sssd ---
# [INFO] Skipping the execution.
# [INFO]
# [INFO] --- maven-resources-plugin:3.0.1:testResources (default-testResources) @ integration-arquillian-tests-sssd ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /content/keycloak/testsuite/integration-arquillian/tests/other/sssd/src/test/resources
# [INFO]
# [INFO] --- maven-antrun-plugin:1.8:run (clean-second-cache-server-arquillian-bug-workaround) @ integration-arquillian-tests-sssd ---
# [INFO] Skipping Antrun execution
# [INFO]
# [INFO] --- maven-resources-plugin:3.0.1:copy-resources (copy-admin-user-json-file) @ integration-arquillian-tests-sssd ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] Copying 1 resource
# [INFO]
# [INFO] --- maven-compiler-plugin:3.8.1-jboss-1:testCompile (default-testCompile) @ integration-arquillian-tests-sssd ---
# [INFO] Changes detected - recompiling the module!
# [INFO] Compiling 1 source file to /content/keycloak/testsuite/integration-arquillian/tests/other/sssd/target/test-classes
# [WARNING] bootstrap class path not set in conjunction with -source 8
# [INFO]
# [INFO] --- shrinkwrap-resolver-maven-plugin:3.1.4:propagate-execution-context (default) @ integration-arquillian-tests-sssd ---
# [INFO]
# [INFO] --- maven-surefire-plugin:2.22.2:test (default-test) @ integration-arquillian-tests-sssd ---
# [INFO]
# [INFO] --- maven-jar-plugin:2.2:jar (default-jar) @ integration-arquillian-tests-sssd ---
# [WARNING] JAR will be empty - no content was marked for inclusion!
# [INFO] Building jar: /content/keycloak/testsuite/integration-arquillian/tests/other/sssd/target/integration-arquillian-tests-sssd-14.0.0-SNAPSHOT.jar
# [INFO]
# [INFO] --- maven-source-plugin:3.1.0:jar-no-fork (attach-sources) @ integration-arquillian-tests-sssd ---
# [INFO] No sources in project. Archive not created.
# [INFO]
# [INFO] --- maven-jar-plugin:2.2:test-jar (default) @ integration-arquillian-tests-sssd ---
# [INFO] Building jar: /content/keycloak/testsuite/integration-arquillian/tests/other/sssd/target/integration-arquillian-tests-sssd-14.0.0-SNAPSHOT-tests.jar
# [INFO]
# [INFO] --- maven-install-plugin:2.5.2:install (default-install) @ integration-arquillian-tests-sssd ---
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/tests/other/sssd/target/integration-arquillian-tests-sssd-14.0.0-SNAPSHOT.jar to /root/.m2/repository/org/keycloak/testsuite/integration-arquillian-tests-sssd/14.0.0-SNAPSHOT/integration-arquillian-tests-sssd-14.0.0-SNAPSHOT.jar
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/tests/other/sssd/pom.xml to /root/.m2/repository/org/keycloak/testsuite/integration-arquillian-tests-sssd/14.0.0-SNAPSHOT/integration-arquillian-tests-sssd-14.0.0-SNAPSHOT.pom
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/tests/other/sssd/target/integration-arquillian-tests-sssd-14.0.0-SNAPSHOT-tests.jar to /root/.m2/repository/org/keycloak/testsuite/integration-arquillian-tests-sssd/14.0.0-SNAPSHOT/integration-arquillian-tests-sssd-14.0.0-SNAPSHOT-tests.jar
# [INFO] ------------------------------------------------------------------------
# [INFO] Reactor Summary for Keycloak Arquillian Integration TestSuite 14.0.0-SNAPSHOT:
# [INFO]
# [INFO] Keycloak Arquillian Integration TestSuite .......... SUCCESS [  1.435 s]
# [INFO] Test apps .......................................... SUCCESS [  0.049 s]
# [INFO] Test apps distribution ............................. SUCCESS [  2.443 s]
# [INFO] Keycloak Authz: PhotoZ  Test Parent ................ SUCCESS [  0.020 s]
# [INFO] Keycloak Authz Test: Photoz RESTful API ............ SUCCESS [  3.363 s]
# [INFO] Keycloak Authz Tests: Photoz HTML5 Client .......... SUCCESS [  0.412 s]
# [INFO] Keycloak Authz Tests: Hello World Example .......... SUCCESS [  0.051 s]
# [INFO] Keycloak Authz: Servlet Authorization Test ......... SUCCESS [  0.282 s]
# [INFO] Keycloak Authz: Simple Servlet App with Policy Enforcer SUCCESS [  0.054 s]
# [INFO] integration-arquillian-test-apps-servlets .......... SUCCESS [  1.261 s]
# [INFO] Keycloak Test App Profile JEE ...................... SUCCESS [  0.410 s]
# [INFO] integration-arquillian-test-apps-cors-parent ....... SUCCESS [  0.066 s]
# [INFO] Angular Product Portal JS .......................... SUCCESS [  0.953 s]
# [INFO] JAX-RS Database Service Using OAuth Bearer Tokens .. SUCCESS [  0.210 s]
# [INFO] Fuse Test Applications ............................. SUCCESS [  0.027 s]
# [INFO] Customer Portal - Secured in Karaf/Fuse ............ SUCCESS [  1.909 s]
# [INFO] CXF JAXRS Example - Secured in Karaf/Fuse .......... SUCCESS [  0.647 s]
# [INFO] CXF JAXRS Example - Secured in Karaf/Fuse 7 on Undertow SUCCESS [  0.386 s]
# [INFO] CXF JAXWS Example - Secured in Karaf/Fuse .......... SUCCESS [  0.480 s]
# [INFO] CXF JAXWS Example - Secured in Karaf/Fuse 7 on Undertow SUCCESS [  0.564 s]
# [INFO] Product Portal - Secured in Karaf/Fuse ............. SUCCESS [  0.571 s]
# [INFO] Product Portal - Secured in Karaf/Fuse 7 on Undertow SUCCESS [  0.425 s]
# [INFO] Camel endpoint example - Secured in Karaf/Fuse ..... SUCCESS [  0.776 s]
# [INFO] Camel endpoint example - Secured in Karaf/Fuse 7.0 on Undertow SUCCESS [  0.445 s]
# [INFO] Keycloak Fuse Example - Features ................... SUCCESS [  0.176 s]
# [INFO] Keycloak Examples - External Config ................ SUCCESS [  0.315 s]
# [INFO] spring-boot-adapter-app ............................ SUCCESS [  0.553 s]
# [INFO] Servers ............................................ SUCCESS [  0.010 s]
# [INFO] Auth Server ........................................ SUCCESS [  0.011 s]
# [INFO] Auth Server Services ............................... SUCCESS [  0.010 s]
# [INFO] Auth Server Services - Testsuite Providers ......... SUCCESS [  4.221 s]
# [INFO] Auth Server - JBoss ................................ SUCCESS [  0.012 s]
# [INFO] Test Util .......................................... SUCCESS [  1.292 s]
# [INFO] Auth Server - Undertow ............................. SUCCESS [  1.733 s]
# [INFO] App Server ......................................... SUCCESS [  0.010 s]
# [INFO] App Server - SPI ................................... SUCCESS [  0.110 s]
# [INFO] App Server - JBoss ................................. SUCCESS [  0.011 s]
# [INFO] App Server - Karaf ................................. SUCCESS [  0.030 s]
# [INFO] App Server - Tomcat ................................ SUCCESS [  0.017 s]
# [INFO] App Server - Undertow .............................. SUCCESS [  0.626 s]
# [INFO] App Server - Jetty Parent .......................... SUCCESS [  0.018 s]
# [INFO] Cache Server ....................................... SUCCESS [  0.010 s]
# [INFO] Cache Server - JBoss Family ........................ SUCCESS [  0.012 s]
# [INFO] Tests .............................................. SUCCESS [  0.105 s]
# [INFO] Base TestSuite ..................................... SUCCESS [01:14 min]
# [INFO] Other Tests Modules ................................ SUCCESS [  0.024 s]
# [INFO] Adapter Tests ...................................... SUCCESS [  0.016 s]
# [INFO] Adapter Tests - JBoss .............................. SUCCESS [  0.012 s]
# [INFO] Adapter Tests - Karaf .............................. SUCCESS [  0.013 s]
# [INFO] Adapter Tests - WAS ................................ SUCCESS [  0.028 s]
# [INFO] Adapter Tests - WLS ................................ SUCCESS [  0.013 s]
# [INFO] SSSD tests ......................................... SUCCESS [  2.058 s]
# [INFO] ------------------------------------------------------------------------
# [INFO] BUILD SUCCESS
# [INFO] ------------------------------------------------------------------------
# [INFO] Total time:  01:47 min
# [INFO] Finished at: 2021-06-07T13:25:12Z
# [INFO] ------------------------------------------------------------------------

# %%
# !cd keycloak && mvn -f testsuite/integration-arquillian/pom.xml clean install -fae
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# 14:50:25,747 INFO  [org.keycloak.testsuite.util.URLUtils] current URL:  https://localhost:8543/auth/realms/test/super-random-page
# 14:50:25,747 INFO  [org.keycloak.testsuite.util.URLUtils] navigating to https://localhost:8543/auth/realms/test/super-random-page
# 14:50:25,747 INFO  [org.keycloak.testsuite.util.URLUtils] target URL equals current URL - refreshing the page
# 14:50:25,762 INFO  [org.keycloak.testsuite.util.URLUtils] new current URL:  https://localhost:8543/auth/realms/test/super-random-page
# 14:50:25,762 INFO  [org.keycloak.testsuite.util.URLUtils] navigation complete
# 14:50:25,762 INFO  [org.keycloak.testsuite.saml.LogoutTest] deleting cookies in 'test' realm
# 14:50:25,817 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 0: class org.keycloak.testsuite.util.saml.CreateAuthnRequestStepBuilder
# 14:50:25,818 INFO  [org.keycloak.testsuite.util.SamlClient] Executing HTTP request to https://localhost:8543/auth/realms/demo/protocol/saml
# 14:50:25,832 DEBUG [org.keycloak.testsuite.util.SamlClient$RedirectStrategyWithSwitchableFollowRedirect] Redirect requested to location 'https://localhost:8543/auth/realms/demo/login-actions/authenticate?client_id=http%3A%2F%2Flocalhost%3A8280%2Fsales-post%2F&tab_id=eaGaRsqNF6U'
# 14:50:25,836 INFO  [org.keycloak.testsuite.util.SamlClient] Landed to https://localhost:8543/auth/realms/demo/login-actions/authenticate?client_id=http%3A%2F%2Flocalhost%3A8280%2Fsales-post%2F&tab_id=eaGaRsqNF6U
# 14:50:25,836 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 1: class org.keycloak.testsuite.util.saml.LoginBuilder
# 14:50:25,837 DEBUG [org.keycloak.testsuite.util.SamlClient] Disabling following redirects
# 14:50:25,837 INFO  [org.keycloak.testsuite.util.SamlClient] Executing HTTP request to https://localhost:8543/auth/realms/demo/login-actions/authenticate?session_code=HGQe5oeqEujsN-fyNWUyDTYOdseTCvOiueTdMpZDlAs&execution=e2b6beba-360a-4f2b-91f6-0e12632a3de2&client_id=http%3A%2F%2Flocalhost%3A8280%2Fsales-post%2F&tab_id=eaGaRsqNF6U
# 14:50:25,848 INFO  [org.keycloak.testsuite.util.SamlClient] Landed to https://localhost:8543/auth/realms/demo/login-actions/authenticate?session_code=HGQe5oeqEujsN-fyNWUyDTYOdseTCvOiueTdMpZDlAs&execution=e2b6beba-360a-4f2b-91f6-0e12632a3de2&client_id=http%3A%2F%2Flocalhost%3A8280%2Fsales-post%2F&tab_id=eaGaRsqNF6U
# 14:50:25,848 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 3: class org.keycloak.testsuite.util.saml.ModifySamlResponseStepBuilder
# 14:50:25,850 INFO  [org.keycloak.testsuite.util.SamlClient] Last step returned no request, continuing with next step.
# 14:50:25,850 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 4: class org.keycloak.testsuite.util.saml.CreateAuthnRequestStepBuilder
# 14:50:25,851 INFO  [org.keycloak.testsuite.util.SamlClient] Executing HTTP request to https://localhost:8543/auth/realms/demo/protocol/saml
# 14:50:25,855 DEBUG [org.keycloak.testsuite.util.SamlClient$RedirectStrategyWithSwitchableFollowRedirect] Redirect requested to location 'https://localhost:8543/auth/realms/demo/login-actions/authenticate?client_id=http%3A%2F%2Flocalhost%3A8280%2Fsales-post2%2F&tab_id=sn910qioTbQ'
# 14:50:25,860 INFO  [org.keycloak.testsuite.util.SamlClient] Landed to https://localhost:8543/auth/realms/demo/login-actions/authenticate?client_id=http%3A%2F%2Flocalhost%3A8280%2Fsales-post2%2F&tab_id=sn910qioTbQ
# 14:50:25,860 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 5: class org.keycloak.testsuite.util.saml.LoginBuilder
# 14:50:25,860 INFO  [org.keycloak.testsuite.util.SamlClient] Last step returned no request, continuing with next step.
# 14:50:25,860 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 6: class org.keycloak.testsuite.util.SamlClient$DoNotFollowRedirectStep
# 14:50:25,860 INFO  [org.keycloak.testsuite.util.SamlClient] Last step returned no request, continuing with next step.
# 14:50:25,860 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 7: class org.keycloak.testsuite.util.saml.ModifySamlResponseStepBuilder
# 14:50:25,861 INFO  [org.keycloak.testsuite.util.SamlClient] Last step returned no request, continuing with next step.
# 14:50:25,862 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 8: class org.keycloak.testsuite.util.SamlClientBuilder$$Lambda$5301/0x0000000842541440
# 14:50:25,862 INFO  [org.keycloak.testsuite.util.SamlClient] Last step returned no request, continuing with next step.
# 14:50:25,862 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 9: class org.keycloak.testsuite.util.saml.CreateLogoutRequestStepBuilder
# 14:50:25,863 DEBUG [org.keycloak.testsuite.util.SamlClient] Disabling following redirects
# 14:50:25,863 INFO  [org.keycloak.testsuite.util.SamlClient] Executing HTTP request to https://localhost:8543/auth/realms/demo/protocol/saml?SAMLRequest=jZJPa9wwEMW%2FyqL7xPpnySt2DYWlwZD00JQeeiljWeoabMmxZMjHj71uIOkh9Dij9%2Bb3ZtAp4ThM5iH%2BiUv%2B7p4Xl%2FLhZRxCMreXM1nmYCKmPpmAo0smW%2FP05fHB8DtqpjnmaONAdsvnYkzJzbmPgbwD%2FLflsgbrA27FmVxznpIpiiFaHK4xZVOVUhS45GsxOxzGVHRujMVbvmJDkUNzOZPm8ps7VoqWMlAcNUhXCjjaDoEK6qxHLSlXqzilxTUhZQz5TDjlDKgCqn8waUpqeHlXKf6LHH66Od1CrYFJfdpI5uad6y3mx5S8omuWwSWY1ro4Fe%2Flu%2FfbeoXmcvga5xHz5%2BfZOn0H%2FiY1ecaQehcyqe9BU4nWCQqtth6klhpQawZd6YUWXApf8b%2F0HbjTJ%2FPk0rZOEzr3UretbrWqPIj2WK1TuIJWiQ6ElFrxo3LI0RgUinplO9BatyAZs1CVQkDnrddVpRjzbGf9M%2F6t%2BeH31a8%3D
# 14:50:25,867 INFO  [org.keycloak.testsuite.util.SamlClient] Landed to https://localhost:8543/auth/realms/demo/protocol/saml?SAMLRequest=jZJPa9wwEMW%2FyqL7xPpnySt2DYWlwZD00JQeeiljWeoabMmxZMjHj71uIOkh9Dij9%2Bb3ZtAp4ThM5iH%2BiUv%2B7p4Xl%2FLhZRxCMreXM1nmYCKmPpmAo0smW%2FP05fHB8DtqpjnmaONAdsvnYkzJzbmPgbwD%2FLflsgbrA27FmVxznpIpiiFaHK4xZVOVUhS45GsxOxzGVHRujMVbvmJDkUNzOZPm8ps7VoqWMlAcNUhXCjjaDoEK6qxHLSlXqzilxTUhZQz5TDjlDKgCqn8waUpqeHlXKf6LHH66Od1CrYFJfdpI5uad6y3mx5S8omuWwSWY1ro4Fe%2Flu%2FfbeoXmcvga5xHz5%2BfZOn0H%2FiY1ecaQehcyqe9BU4nWCQqtth6klhpQawZd6YUWXApf8b%2F0HbjTJ%2FPk0rZOEzr3UretbrWqPIj2WK1TuIJWiQ6ElFrxo3LI0RgUinplO9BatyAZs1CVQkDnrddVpRjzbGf9M%2F6t%2BeH31a8%3D
# 14:50:25,867 INFO  [org.keycloak.testsuite.util.SamlClient] Going to extract response
# 14:50:25,869 INFO  [org.keycloak.testsuite.saml.LogoutTest] removing test realms after test method
# 14:50:25,869 INFO  [org.keycloak.testsuite.saml.LogoutTest] removing realm: demo
# 14:50:26,164 INFO  [org.keycloak.testsuite.saml.LogoutTest] [LogoutTest] testFrontchannelLogoutWithRedirectUrlDifferentBrowser() FINISHED
#
#
# 14:50:26,164 INFO  [org.keycloak.testsuite.saml.LogoutTest] [LogoutTest] testLogoutDifferentBrowser() STARTED
# 14:50:26,314 DEBUG [org.keycloak.testsuite.saml.LogoutTest] loading test realms
# Loaded realm demo
# 14:50:26,314 INFO  [org.keycloak.testsuite.saml.LogoutTest] importing test realms
# 14:50:26,314 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying demo for SSL
# 14:50:26,314 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/missing-assertion-sig/
# 14:50:26,314 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/bad-assertion-sales-post-sig/
# 14:50:26,314 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/input-portal/
# 14:50:26,314 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-assertion-and-response-sig/
# 14:50:26,314 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post2/
# 14:50:26,314 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/different-cookie-name/
# 14:50:26,314 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post/
# 14:50:26,314 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-clock-skew/
# 14:50:26,314 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-passive/
# 14:50:26,314 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-sig/
# 14:50:26,314 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-sig-transient/
# 14:50:26,314 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-sig-persistent/
# 14:50:26,314 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-sig-email/
# 14:50:26,314 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/bad-realm-sales-post-sig/
# 14:50:26,314 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/bad-client-sales-post-sig/
# 14:50:26,314 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-enc/
# 14:50:26,314 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-enc-sign-assertions-only/
# 14:50:26,314 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/employee-sig/
# 14:50:26,314 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/employee-sig-redir-noidpkey/
# 14:50:26,314 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/employee-sig-redir-opt-noidpkey/
# 14:50:26,314 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/employee-sig-post-noidpkey/
# 14:50:26,314 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/employee/
# 14:50:26,314 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/employee-acs/
# 14:50:26,314 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/employee2/
# 14:50:26,314 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/employee-dom/
# 14:50:26,315 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/employee-sig-front/
# 14:50:26,315 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/ecp-sp/
# 14:50:26,315 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/employee-role-mapping/
# 14:50:26,315 DEBUG [org.keycloak.testsuite.saml.LogoutTest] --importing realm: demo
# 14:50:27,146 INFO  [org.keycloak.testsuite.util.URLUtils] starting navigation
# 14:50:27,147 INFO  [org.keycloak.testsuite.util.URLUtils] current URL:  https://localhost:8543/auth/realms/test/super-random-page
# 14:50:27,147 INFO  [org.keycloak.testsuite.util.URLUtils] navigating to https://localhost:8543/auth/realms/test/super-random-page
# 14:50:27,147 INFO  [org.keycloak.testsuite.util.URLUtils] target URL equals current URL - refreshing the page
# 14:50:27,161 INFO  [org.keycloak.testsuite.util.URLUtils] new current URL:  https://localhost:8543/auth/realms/test/super-random-page
# 14:50:27,162 INFO  [org.keycloak.testsuite.util.URLUtils] navigation complete
# 14:50:27,162 INFO  [org.keycloak.testsuite.saml.LogoutTest] deleting cookies in 'test' realm
# 14:50:27,209 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 0: class org.keycloak.testsuite.util.saml.CreateAuthnRequestStepBuilder
# 14:50:27,210 INFO  [org.keycloak.testsuite.util.SamlClient] Executing HTTP request to https://localhost:8543/auth/realms/demo/protocol/saml
# 14:50:27,224 DEBUG [org.keycloak.testsuite.util.SamlClient$RedirectStrategyWithSwitchableFollowRedirect] Redirect requested to location 'https://localhost:8543/auth/realms/demo/login-actions/authenticate?client_id=http%3A%2F%2Flocalhost%3A8280%2Fsales-post%2F&tab_id=0Qeqrjupofo'
# 14:50:27,226 INFO  [org.keycloak.testsuite.util.SamlClient] Landed to https://localhost:8543/auth/realms/demo/login-actions/authenticate?client_id=http%3A%2F%2Flocalhost%3A8280%2Fsales-post%2F&tab_id=0Qeqrjupofo
# 14:50:27,227 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 1: class org.keycloak.testsuite.util.saml.LoginBuilder
# 14:50:27,227 DEBUG [org.keycloak.testsuite.util.SamlClient] Disabling following redirects
# 14:50:27,227 INFO  [org.keycloak.testsuite.util.SamlClient] Executing HTTP request to https://localhost:8543/auth/realms/demo/login-actions/authenticate?session_code=DvksvK6GGGKkmM2vxqhZjpqbKeyUl2MdCbPA7SDvENE&execution=9e64bc4c-02e0-4736-9a02-192263ce1236&client_id=http%3A%2F%2Flocalhost%3A8280%2Fsales-post%2F&tab_id=0Qeqrjupofo
# 14:50:27,236 INFO  [org.keycloak.testsuite.util.SamlClient] Landed to https://localhost:8543/auth/realms/demo/login-actions/authenticate?session_code=DvksvK6GGGKkmM2vxqhZjpqbKeyUl2MdCbPA7SDvENE&execution=9e64bc4c-02e0-4736-9a02-192263ce1236&client_id=http%3A%2F%2Flocalhost%3A8280%2Fsales-post%2F&tab_id=0Qeqrjupofo
# 14:50:27,236 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 3: class org.keycloak.testsuite.util.saml.ModifySamlResponseStepBuilder
# 14:50:27,237 INFO  [org.keycloak.testsuite.util.SamlClient] Last step returned no request, continuing with next step.
# 14:50:27,237 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 4: class org.keycloak.testsuite.util.saml.CreateAuthnRequestStepBuilder
# 14:50:27,239 INFO  [org.keycloak.testsuite.util.SamlClient] Executing HTTP request to https://localhost:8543/auth/realms/demo/protocol/saml
# 14:50:27,249 DEBUG [org.keycloak.testsuite.util.SamlClient$RedirectStrategyWithSwitchableFollowRedirect] Redirect requested to location 'https://localhost:8543/auth/realms/demo/login-actions/authenticate?client_id=http%3A%2F%2Flocalhost%3A8280%2Fsales-post2%2F&tab_id=Ezzr7XMAQzo'
# 14:50:27,264 INFO  [org.keycloak.testsuite.util.SamlClient] Landed to https://localhost:8543/auth/realms/demo/login-actions/authenticate?client_id=http%3A%2F%2Flocalhost%3A8280%2Fsales-post2%2F&tab_id=Ezzr7XMAQzo
# 14:50:27,264 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 5: class org.keycloak.testsuite.util.saml.LoginBuilder
# 14:50:27,264 INFO  [org.keycloak.testsuite.util.SamlClient] Last step returned no request, continuing with next step.
# 14:50:27,264 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 6: class org.keycloak.testsuite.util.SamlClient$DoNotFollowRedirectStep
# 14:50:27,264 INFO  [org.keycloak.testsuite.util.SamlClient] Last step returned no request, continuing with next step.
# 14:50:27,264 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 7: class org.keycloak.testsuite.util.saml.ModifySamlResponseStepBuilder
# 14:50:27,265 INFO  [org.keycloak.testsuite.util.SamlClient] Last step returned no request, continuing with next step.
# 14:50:27,265 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 8: class org.keycloak.testsuite.util.SamlClientBuilder$$Lambda$5301/0x0000000842541440
# 14:50:27,265 INFO  [org.keycloak.testsuite.util.SamlClient] Last step returned no request, continuing with next step.
# 14:50:27,265 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 9: class org.keycloak.testsuite.util.saml.CreateLogoutRequestStepBuilder
# 14:50:27,267 DEBUG [org.keycloak.testsuite.util.SamlClient] Disabling following redirects
# 14:50:27,267 INFO  [org.keycloak.testsuite.util.SamlClient] Executing HTTP request to https://localhost:8543/auth/realms/demo/protocol/saml
# 14:50:27,271 INFO  [org.keycloak.testsuite.util.SamlClient] Landed to https://localhost:8543/auth/realms/demo/protocol/saml
# 14:50:27,271 INFO  [org.keycloak.testsuite.util.SamlClient] Going to extract response
# 14:50:27,275 INFO  [org.keycloak.testsuite.saml.LogoutTest] removing test realms after test method
# 14:50:27,275 INFO  [org.keycloak.testsuite.saml.LogoutTest] removing realm: demo
# 14:50:27,616 INFO  [org.keycloak.testsuite.saml.LogoutTest] [LogoutTest] testLogoutDifferentBrowser() FINISHED
#
#
# 14:50:27,616 INFO  [org.keycloak.testsuite.saml.LogoutTest] [LogoutTest] testLogoutMandatoryDestinationSetRedirect() STARTED
# 14:50:27,771 DEBUG [org.keycloak.testsuite.saml.LogoutTest] loading test realms
# Loaded realm demo
# 14:50:27,771 INFO  [org.keycloak.testsuite.saml.LogoutTest] importing test realms
# 14:50:27,771 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying demo for SSL
# 14:50:27,771 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/missing-assertion-sig/
# 14:50:27,771 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/bad-assertion-sales-post-sig/
# 14:50:27,771 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/input-portal/
# 14:50:27,771 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-assertion-and-response-sig/
# 14:50:27,771 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post2/
# 14:50:27,771 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/different-cookie-name/
# 14:50:27,771 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post/
# 14:50:27,771 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-clock-skew/
# 14:50:27,771 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-passive/
# 14:50:27,771 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-sig/
# 14:50:27,771 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-sig-transient/
# 14:50:27,772 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-sig-persistent/
# 14:50:27,772 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-sig-email/
# 14:50:27,772 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/bad-realm-sales-post-sig/
# 14:50:27,772 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/bad-client-sales-post-sig/
# 14:50:27,772 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-enc/
# 14:50:27,772 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-enc-sign-assertions-only/
# 14:50:27,772 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/employee-sig/
# 14:50:27,772 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/employee-sig-redir-noidpkey/
# 14:50:27,772 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/employee-sig-redir-opt-noidpkey/
# 14:50:27,772 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/employee-sig-post-noidpkey/
# 14:50:27,772 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/employee/
# 14:50:27,772 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/employee-acs/
# 14:50:27,772 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/employee2/
# 14:50:27,772 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/employee-dom/
# 14:50:27,772 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/employee-sig-front/
# 14:50:27,772 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/ecp-sp/
# 14:50:27,772 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/employee-role-mapping/
# 14:50:27,772 DEBUG [org.keycloak.testsuite.saml.LogoutTest] --importing realm: demo
# 14:50:28,613 INFO  [org.keycloak.testsuite.util.URLUtils] starting navigation
# 14:50:28,614 INFO  [org.keycloak.testsuite.util.URLUtils] current URL:  https://localhost:8543/auth/realms/test/super-random-page
# 14:50:28,614 INFO  [org.keycloak.testsuite.util.URLUtils] navigating to https://localhost:8543/auth/realms/test/super-random-page
# 14:50:28,614 INFO  [org.keycloak.testsuite.util.URLUtils] target URL equals current URL - refreshing the page
# 14:50:28,629 INFO  [org.keycloak.testsuite.util.URLUtils] new current URL:  https://localhost:8543/auth/realms/test/super-random-page
# 14:50:28,629 INFO  [org.keycloak.testsuite.util.URLUtils] navigation complete
# 14:50:28,629 INFO  [org.keycloak.testsuite.saml.LogoutTest] deleting cookies in 'test' realm
# 14:50:28,711 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 0: class org.keycloak.testsuite.util.saml.CreateAuthnRequestStepBuilder
# 14:50:28,713 INFO  [org.keycloak.testsuite.util.SamlClient] Executing HTTP request to https://localhost:8543/auth/realms/demo/protocol/saml
# 14:50:28,740 DEBUG [org.keycloak.testsuite.util.SamlClient$RedirectStrategyWithSwitchableFollowRedirect] Redirect requested to location 'https://localhost:8543/auth/realms/demo/login-actions/authenticate?client_id=http%3A%2F%2Flocalhost%3A8280%2Fsales-post%2F&tab_id=dLQzkbxcWkU'
# 14:50:28,743 INFO  [org.keycloak.testsuite.util.SamlClient] Landed to https://localhost:8543/auth/realms/demo/login-actions/authenticate?client_id=http%3A%2F%2Flocalhost%3A8280%2Fsales-post%2F&tab_id=dLQzkbxcWkU
# 14:50:28,743 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 1: class org.keycloak.testsuite.util.saml.LoginBuilder
# 14:50:28,743 DEBUG [org.keycloak.testsuite.util.SamlClient] Disabling following redirects
# 14:50:28,743 INFO  [org.keycloak.testsuite.util.SamlClient] Executing HTTP request to https://localhost:8543/auth/realms/demo/broker/saml-broker/login?client_id=http%3A%2F%2Flocalhost%3A8280%2Fsales-post%2F&tab_id=dLQzkbxcWkU&session_code=prFSh3-ndl0mdmNc7eV_RCeB4tQU0mfuI9rkPY1SPls
# 14:50:28,746 INFO  [org.keycloak.testsuite.util.SamlClient] Landed to https://localhost:8543/auth/realms/demo/broker/saml-broker/login?client_id=http%3A%2F%2Flocalhost%3A8280%2Fsales-post%2F&tab_id=dLQzkbxcWkU&session_code=prFSh3-ndl0mdmNc7eV_RCeB4tQU0mfuI9rkPY1SPls
# 14:50:28,746 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 3: class org.keycloak.testsuite.util.saml.ModifySamlResponseStepBuilder
# 14:50:28,749 DEBUG [org.keycloak.testsuite.util.saml.SamlDocumentStepBuilder]   ---> <samlp:Response xmlns:samlp="urn:oasis:names:tc:SAML:2.0:protocol" xmlns:saml="urn:oasis:names:tc:SAML:2.0:assertion" ID="ID_8daa07cd-31e6-44bd-b4e4-d154ab6a8d93" Version="2.0" IssueInstant="2021-06-07T14:50:28.747Z" Destination="https://localhost:8543/auth/realms/demo/broker/saml-broker/endpoint" InResponseTo="ID_04001b1d-5a54-4858-a260-f346639ece42"><saml:Issuer>https://saml.idp/saml</saml:Issuer><samlp:Status><samlp:StatusCode Value="urn:oasis:names:tc:SAML:2.0:status:Success"></samlp:StatusCode></samlp:Status><saml:Assertion xmlns:saml="urn:oasis:names:tc:SAML:2.0:assertion" xmlns="urn:oasis:names:tc:SAML:2.0:assertion" ID="ID_a135ca99-16ec-49f3-acf8-9ac34c8906d1" Version="2.0" IssueInstant="2021-06-07T14:50:28.747Z"><saml:Issuer>https://saml.idp/saml</saml:Issuer><saml:Subject><saml:NameID Format="urn:oasis:names:tc:SAML:1.1:nameid-format:emailAddress" SPProvidedID="spProvidedId" SPNameQualifier="spNameQualifier" NameQualifier="nameQualifier">a@b.c</saml:NameID><saml:SubjectConfirmation Method="urn:oasis:names:tc:SAML:2.0:cm:bearer"><saml:SubjectConfirmationData InResponseTo="ID_04001b1d-5a54-4858-a260-f346639ece42" NotOnOrAfter="2021-06-19T04:37:06.747Z" Recipient="https://localhost:8543/auth/realms/demo/broker/saml-broker/endpoint"></saml:SubjectConfirmationData></saml:SubjectConfirmation></saml:Subject><saml:Conditions NotBefore="2021-06-07T14:50:26.747Z" NotOnOrAfter="2021-06-19T04:37:06.747Z"><saml:AudienceRestriction><saml:Audience>https://localhost:8543/auth/realms/demo</saml:Audience></saml:AudienceRestriction></saml:Conditions><saml:AuthnStatement AuthnInstant="2021-06-07T14:50:28.747Z" SessionIndex="idp:1a56c7d9-d78e-425e-a3e2-2a5dd1467405"><saml:AuthnContext><saml:AuthnContextClassRef>urn:oasis:names:tc:SAML:2.0:ac:classes:unspecified</saml:AuthnContextClassRef></saml:AuthnContext></saml:AuthnStatement></saml:Assertion></samlp:Response>
# 14:50:28,749 INFO  [org.keycloak.testsuite.util.SamlClient] Executing HTTP request to https://localhost:8543/auth/realms/demo/broker/saml-broker/endpoint?RelayState=LHojyroTWlTwLh_b1-bgPAzjBLFSkXx21m906ZYDexc.dLQzkbxcWkU.http%3A%2F%2Flocalhost%3A8280%2Fsales-post%2F&SAMLResponse=rVRba9swFP4rxu%2BKb%2FJNJGFZwyCwtltT%2BrCXIUvHRJstGUse%2FfmTXDs0oQ1d2Jt0rt93bktN26YjD6A7JTV4z20jNRmFK3%2FoJVFUC00kbUETw8h%2Bc%2FuVxIuQdL0yiqnGf%2BVy2YNqDb0RSvrebrvyd9ufBac0zBlHSQQZwrjiqMKAEY9STKuMFrxMfO8Jem29Vr4NYl21HmAntaHSWFEYRyjMUJg%2FRpikIYmLRY7zH763BW2EpGb0PBjTaRIEjWK0OShtSJHiJKCDOQQ90KbVAYdWBVWvfkMfOC5oeoPknRLS2MxyrtKjGuGHOAyjKuIopSlGuEgLROMsRHWCsywpgQGO%2FfXSRSMj7H49A3GyheDd%2BFgGr02WLx3ZG2oGffq7URy8J9oMcLnSerQm%2B4Ex0NpCCM6jnIkmkJu5Q9f0dHT51wmgUZIyWpYoyoAhXNYJoqwuUElZgllRhhmPrpyA6wpvi1b9Amam353lsNt6X1TfUvM%2BuWgRjRLBUT2aEmipaDac964B3v7bt179ERy446274487nUvyfaCNqAX0Tn0i8L0zvTzRrumnasEmJi9wT5ncKFkLh8n19RbMQfHLXWItqYD2Lva7gbbU0CsXwrtT5l7e95vaODZz%2F6LyMcQkyUmYTRv8AEx0AlyT%2F8f%2BTiP%2FHpsL6jPVVBVrwYVTa8foM9jGw1vjONP5IO15FQduqTOwFTa9YC8wTjTrDxZlAn90O%2FufJAjOmB1TmoN0lwJa2w5v%2FH7gBO%2Ft7NsoO8nheeXbpSMRTTOW8xLxvACE4xQQTSBGMU05j3CW4zD1Xye1UAw8mzdEN429Jg9Qry8eHEaYs7PiQerODpTdGX6swBvR3tCdyI5VOErnm3Y8qfNSrP8C
# 14:50:28,754 DEBUG [org.keycloak.testsuite.util.SamlClient$RedirectStrategyWithSwitchableFollowRedirect] Redirect requested to location 'https://localhost:8543/auth/realms/demo/login-actions/first-broker-login?client_id=http%3A%2F%2Flocalhost%3A8280%2Fsales-post%2F&tab_id=dLQzkbxcWkU'
# 14:50:28,758 INFO  [org.keycloak.testsuite.util.SamlClient] Landed to https://localhost:8543/auth/realms/demo/login-actions/first-broker-login?client_id=http%3A%2F%2Flocalhost%3A8280%2Fsales-post%2F&tab_id=dLQzkbxcWkU
# 14:50:28,759 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 4: class org.keycloak.testsuite.util.saml.UpdateProfileBuilder
# 14:50:28,759 DEBUG [org.keycloak.testsuite.util.SamlClient] Disabling following redirects
# 14:50:28,759 INFO  [org.keycloak.testsuite.util.SamlClient] Executing HTTP request to https://localhost:8543/auth/realms/demo/login-actions/first-broker-login?session_code=5ZkA-cVquLDSJSEpuqy1wTv1tj49vSf79jQEbAPifZE&execution=e30cc962-d479-4cd0-9b90-88815c87c8f7&client_id=http%3A%2F%2Flocalhost%3A8280%2Fsales-post%2F&tab_id=dLQzkbxcWkU
# 14:50:28,764 INFO  [org.keycloak.testsuite.util.SamlClient] Landed to https://localhost:8543/auth/realms/demo/login-actions/first-broker-login?session_code=5ZkA-cVquLDSJSEpuqy1wTv1tj49vSf79jQEbAPifZE&execution=e30cc962-d479-4cd0-9b90-88815c87c8f7&client_id=http%3A%2F%2Flocalhost%3A8280%2Fsales-post%2F&tab_id=dLQzkbxcWkU
# 14:50:28,764 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 6: class org.keycloak.testsuite.util.SamlClientBuilder$$Lambda$2258/0x000000084198b440
# 14:50:28,764 DEBUG [org.keycloak.testsuite.util.SamlClient] Disabling following redirects
# 14:50:28,764 INFO  [org.keycloak.testsuite.util.SamlClient] Executing HTTP request to https://localhost:8543/auth/realms/demo/broker/after-first-broker-login?session_code=riZQ8izYk3eGV_kSHu2Oo4T35fYzldrwVMVN5MShdVk&client_id=http%3A%2F%2Flocalhost%3A8280%2Fsales-post%2F&tab_id=dLQzkbxcWkU
# 14:50:28,772 INFO  [org.keycloak.testsuite.util.SamlClient] Landed to https://localhost:8543/auth/realms/demo/broker/after-first-broker-login?session_code=riZQ8izYk3eGV_kSHu2Oo4T35fYzldrwVMVN5MShdVk&client_id=http%3A%2F%2Flocalhost%3A8280%2Fsales-post%2F&tab_id=dLQzkbxcWkU
# 14:50:28,773 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 8: class org.keycloak.testsuite.util.saml.ModifySamlResponseStepBuilder
# 14:50:28,774 INFO  [org.keycloak.testsuite.util.SamlClient] Last step returned no request, continuing with next step.
# 14:50:28,774 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 9: class org.keycloak.testsuite.util.saml.CreateLogoutRequestStepBuilder
# 14:50:28,776 DEBUG [org.keycloak.testsuite.util.SamlClient] Disabling following redirects
# 14:50:28,776 INFO  [org.keycloak.testsuite.util.SamlClient] Executing HTTP request to https://localhost:8543/auth/realms/demo/protocol/saml?SAMLRequest=jZJPa9wwEMW%2FyqL7RLIsrWSxaygsLYa0h6b00EuRpXHXYEuuJUM%2Bfv2ngaSH0OOM3tPvzTCXZMdhMo%2FxV1zyV%2Fy9YMqn53EIyewvV7LMwUSb%2BmSCHTGZ7MzTh8%2BPhj8wM80xRxcHcljeF9uUcM59DOQV4L8ttzVYH%2BxWXMk95ykZSofo7HCPKRstRUntku90RjuMiXocI33JRzcUOTW3K2luP7nFVjvJwa0mEFJ40FUngJeu5PqMQjK7ilNasAkp25CvhDNeADsDU98KYSQzXD8oJX6Q03ec0x5qDUzqy0Yyu3eut5hvU3LN1iwDJpjWml7oa%2Fnh%2FbJuobmdPsZ5tPn99Wyd3kO3S02ebUg9hkzqT8BkVaFiFch2n5FLaJ1EUJp7K3QpEfVf%2BgE86JN5wrSN0wSPz3WntBdozyCYtiDWrUGrOgnat53mlSoEk8a0tmy9bhFQcgWCFwVUrvBQltK7UmnttTtY%2F3z%2F0nxzffUf&SigAlg=http%3A%2F%2Fwww.w3.org%2F2001%2F04%2Fxmldsig-more%23rsa-sha256&Signature=tMBk4D4VELG5RfNUtde9Mc5%2BfJnPBHAu5Kbxt7uYsEjAVYxCnTQnyrZ%2BlZIyEYOGg2B%2B%2FIJ9nHWD%2B0UBqm4%2FQ20zHXh3Vngot2ez7D3f4dX9EPnu%2BO3UjevjMCfsp2rD70NanXqZ%2F%2Fbvis0lZJ7%2FSG5R5XQ0UuZGOsiuHbSWaHU%3D
# 14:50:28,781 INFO  [org.keycloak.testsuite.util.SamlClient] Landed to https://localhost:8543/auth/realms/demo/protocol/saml?SAMLRequest=jZJPa9wwEMW%2FyqL7RLIsrWSxaygsLYa0h6b00EuRpXHXYEuuJUM%2Bfv2ngaSH0OOM3tPvzTCXZMdhMo%2FxV1zyV%2Fy9YMqn53EIyewvV7LMwUSb%2BmSCHTGZ7MzTh8%2BPhj8wM80xRxcHcljeF9uUcM59DOQV4L8ttzVYH%2BxWXMk95ykZSofo7HCPKRstRUntku90RjuMiXocI33JRzcUOTW3K2luP7nFVjvJwa0mEFJ40FUngJeu5PqMQjK7ilNasAkp25CvhDNeADsDU98KYSQzXD8oJX6Q03ec0x5qDUzqy0Yyu3eut5hvU3LN1iwDJpjWml7oa%2Fnh%2FbJuobmdPsZ5tPn99Wyd3kO3S02ebUg9hkzqT8BkVaFiFch2n5FLaJ1EUJp7K3QpEfVf%2BgE86JN5wrSN0wSPz3WntBdozyCYtiDWrUGrOgnat53mlSoEk8a0tmy9bhFQcgWCFwVUrvBQltK7UmnttTtY%2F3z%2F0nxzffUf&SigAlg=http%3A%2F%2Fwww.w3.org%2F2001%2F04%2Fxmldsig-more%23rsa-sha256&Signature=tMBk4D4VELG5RfNUtde9Mc5%2BfJnPBHAu5Kbxt7uYsEjAVYxCnTQnyrZ%2BlZIyEYOGg2B%2B%2FIJ9nHWD%2B0UBqm4%2FQ20zHXh3Vngot2ez7D3f4dX9EPnu%2BO3UjevjMCfsp2rD70NanXqZ%2F%2Fbvis0lZJ7%2FSG5R5XQ0UuZGOsiuHbSWaHU%3D
# 14:50:28,781 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 11: class org.keycloak.testsuite.util.SamlClientBuilder$$Lambda$2255/0x000000084198a040
# 14:50:28,781 INFO  [org.keycloak.testsuite.util.SamlClient] Last step returned no request, continuing with next step.
# 14:50:28,781 INFO  [org.keycloak.testsuite.util.SamlClient] Going to extract response
# 14:50:28,803 INFO  [org.keycloak.testsuite.saml.LogoutTest] removing test realms after test method
# 14:50:28,803 INFO  [org.keycloak.testsuite.saml.LogoutTest] removing realm: demo
# 14:50:29,200 INFO  [org.keycloak.testsuite.saml.LogoutTest] [LogoutTest] testLogoutMandatoryDestinationSetRedirect() FINISHED
#
#
# 14:50:29,200 INFO  [org.keycloak.testsuite.saml.LogoutTest] [LogoutTest] testLogoutDestinationOptionalIfUnsignedPost() STARTED
# 14:50:29,391 DEBUG [org.keycloak.testsuite.saml.LogoutTest] loading test realms
# Loaded realm demo
# 14:50:29,392 INFO  [org.keycloak.testsuite.saml.LogoutTest] importing test realms
# 14:50:29,392 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying demo for SSL
# 14:50:29,392 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/missing-assertion-sig/
# 14:50:29,392 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/bad-assertion-sales-post-sig/
# 14:50:29,392 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/input-portal/
# 14:50:29,392 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-assertion-and-response-sig/
# 14:50:29,392 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post2/
# 14:50:29,392 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/different-cookie-name/
# 14:50:29,392 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post/
# 14:50:29,392 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-clock-skew/
# 14:50:29,392 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-passive/
# 14:50:29,392 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-sig/
# 14:50:29,392 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-sig-transient/
# 14:50:29,392 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-sig-persistent/
# 14:50:29,392 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-sig-email/
# 14:50:29,392 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/bad-realm-sales-post-sig/
# 14:50:29,392 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/bad-client-sales-post-sig/
# 14:50:29,392 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-enc/
# 14:50:29,392 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-enc-sign-assertions-only/
# 14:50:29,392 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/employee-sig/
# 14:50:29,392 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/employee-sig-redir-noidpkey/
# 14:50:29,392 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/employee-sig-redir-opt-noidpkey/
# 14:50:29,392 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/employee-sig-post-noidpkey/
# 14:50:29,392 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/employee/
# 14:50:29,392 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/employee-acs/
# 14:50:29,392 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/employee2/
# 14:50:29,392 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/employee-dom/
# 14:50:29,392 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/employee-sig-front/
# 14:50:29,392 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/ecp-sp/
# 14:50:29,392 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/employee-role-mapping/
# 14:50:29,392 DEBUG [org.keycloak.testsuite.saml.LogoutTest] --importing realm: demo
# 14:50:30,226 INFO  [org.keycloak.testsuite.util.URLUtils] starting navigation
# 14:50:30,226 INFO  [org.keycloak.testsuite.util.URLUtils] current URL:  https://localhost:8543/auth/realms/test/super-random-page
# 14:50:30,226 INFO  [org.keycloak.testsuite.util.URLUtils] navigating to https://localhost:8543/auth/realms/test/super-random-page
# 14:50:30,226 INFO  [org.keycloak.testsuite.util.URLUtils] target URL equals current URL - refreshing the page
# 14:50:30,241 INFO  [org.keycloak.testsuite.util.URLUtils] new current URL:  https://localhost:8543/auth/realms/test/super-random-page
# 14:50:30,241 INFO  [org.keycloak.testsuite.util.URLUtils] navigation complete
# 14:50:30,241 INFO  [org.keycloak.testsuite.saml.LogoutTest] deleting cookies in 'test' realm
# 14:50:30,298 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 0: class org.keycloak.testsuite.util.saml.CreateAuthnRequestStepBuilder
# 14:50:30,299 INFO  [org.keycloak.testsuite.util.SamlClient] Executing HTTP request to https://localhost:8543/auth/realms/demo/protocol/saml
# 14:50:30,319 DEBUG [org.keycloak.testsuite.util.SamlClient$RedirectStrategyWithSwitchableFollowRedirect] Redirect requested to location 'https://localhost:8543/auth/realms/demo/login-actions/authenticate?client_id=http%3A%2F%2Flocalhost%3A8280%2Fsales-post%2F&tab_id=sn5avG0dEog'
# 14:50:30,320 INFO  [org.keycloak.testsuite.util.SamlClient] Landed to https://localhost:8543/auth/realms/demo/login-actions/authenticate?client_id=http%3A%2F%2Flocalhost%3A8280%2Fsales-post%2F&tab_id=sn5avG0dEog
# 14:50:30,320 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 1: class org.keycloak.testsuite.util.saml.LoginBuilder
# 14:50:30,321 DEBUG [org.keycloak.testsuite.util.SamlClient] Disabling following redirects
# 14:50:30,321 INFO  [org.keycloak.testsuite.util.SamlClient] Executing HTTP request to https://localhost:8543/auth/realms/demo/broker/saml-broker/login?client_id=http%3A%2F%2Flocalhost%3A8280%2Fsales-post%2F&tab_id=sn5avG0dEog&session_code=4lHVIn4YfDfvr5ArftZdQ2rZOpzjnNDwyS3TC-lKKVY
# 14:50:30,323 INFO  [org.keycloak.testsuite.util.SamlClient] Landed to https://localhost:8543/auth/realms/demo/broker/saml-broker/login?client_id=http%3A%2F%2Flocalhost%3A8280%2Fsales-post%2F&tab_id=sn5avG0dEog&session_code=4lHVIn4YfDfvr5ArftZdQ2rZOpzjnNDwyS3TC-lKKVY
# 14:50:30,323 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 3: class org.keycloak.testsuite.util.saml.ModifySamlResponseStepBuilder
# 14:50:30,325 DEBUG [org.keycloak.testsuite.util.saml.SamlDocumentStepBuilder]   ---> <samlp:Response xmlns:samlp="urn:oasis:names:tc:SAML:2.0:protocol" xmlns:saml="urn:oasis:names:tc:SAML:2.0:assertion" ID="ID_0c0af64f-e890-4eec-8195-14cb3ba2ad93" Version="2.0" IssueInstant="2021-06-07T14:50:30.324Z" Destination="https://localhost:8543/auth/realms/demo/broker/saml-broker/endpoint" InResponseTo="ID_36757efc-b864-41ac-87a0-cbbb31d7b409"><saml:Issuer>https://saml.idp/saml</saml:Issuer><samlp:Status><samlp:StatusCode Value="urn:oasis:names:tc:SAML:2.0:status:Success"></samlp:StatusCode></samlp:Status><saml:Assertion xmlns:saml="urn:oasis:names:tc:SAML:2.0:assertion" xmlns="urn:oasis:names:tc:SAML:2.0:assertion" ID="ID_5f273bbf-d655-4367-83a4-39e2d59c9199" Version="2.0" IssueInstant="2021-06-07T14:50:30.324Z"><saml:Issuer>https://saml.idp/saml</saml:Issuer><saml:Subject><saml:NameID Format="urn:oasis:names:tc:SAML:1.1:nameid-format:emailAddress" SPProvidedID="spProvidedId" SPNameQualifier="spNameQualifier" NameQualifier="nameQualifier">a@b.c</saml:NameID><saml:SubjectConfirmation Method="urn:oasis:names:tc:SAML:2.0:cm:bearer"><saml:SubjectConfirmationData InResponseTo="ID_36757efc-b864-41ac-87a0-cbbb31d7b409" NotOnOrAfter="2021-06-19T04:37:08.324Z" Recipient="https://localhost:8543/auth/realms/demo/broker/saml-broker/endpoint"></saml:SubjectConfirmationData></saml:SubjectConfirmation></saml:Subject><saml:Conditions NotBefore="2021-06-07T14:50:28.324Z" NotOnOrAfter="2021-06-19T04:37:08.324Z"><saml:AudienceRestriction><saml:Audience>https://localhost:8543/auth/realms/demo</saml:Audience></saml:AudienceRestriction></saml:Conditions><saml:AuthnStatement AuthnInstant="2021-06-07T14:50:30.324Z" SessionIndex="idp:0f41af14-721c-40c8-a8fa-d635cb8232de"><saml:AuthnContext><saml:AuthnContextClassRef>urn:oasis:names:tc:SAML:2.0:ac:classes:unspecified</saml:AuthnContextClassRef></saml:AuthnContext></saml:AuthnStatement></saml:Assertion></samlp:Response>
# 14:50:30,325 INFO  [org.keycloak.testsuite.util.SamlClient] Executing HTTP request to https://localhost:8543/auth/realms/demo/broker/saml-broker/endpoint?RelayState=83Nv-3NuP5mWulwXFrHVBwRfowcIa49XN0Ol4j8xMEE.sn5avG0dEog.http%3A%2F%2Flocalhost%3A8280%2Fsales-post%2F&SAMLResponse=rVRba9swFP4rxu%2BK5VtsiyQsaxgE1mtKH%2FYyZOmYeLMlI8mjP3%2BSa4cmpKELe5PO9fvObaFp23TkCXQnhQbvtW2EJoNw6fdKEEl1rYmgLWhiGNmtb7%2BTaIZJp6SRTDb%2BO5fLHlRrUKaWwve2m6W%2F3fzEDNNqnlQI8gKjBIChPCxSFCasjEsaUV7EvvcCSluvpW%2BDWFete9gKbagwVoSjEOE5wtlzmJAUkxjP4ij54Xsb0KYW1Ayee2M6TYKgkYw2e6kNydMkDmhv9oEC2rQ64NDKoFTyN6jAcUHjGwTvZC2MzSymKj3LAX48z9IMKobKfJ6gJKQWfkYxYmVZxiHPygQX%2FmrhopEBtlpNQJxsVvNueCyC9yaLt47sDDW9Pv7dSA7eC216uFxpPViTXc8YaG0hBKdRTkQjyPXUoWt6Orj86wSkVZTFZVkhPk9TlNiKojymCYoLiHhasCIsiisn4LrC26KVv4CZ8XdnOWw33jepWmo%2BJhfOwkFSc1QNpgRaWjdrzpVrgLd7eFDyT82BO966O%2Fy407kkjz1t6qoG5dRHAt870Ysj7Yp%2BKWdsZPIG95jJjRRV7TC5vt6C2Ut%2BuUusJSVQ5WJ%2FGGhDDb1yIbw7ae7FvVpXxrGZ%2BhcWzzghcUZwPm7wE7C6q8E1%2BX%2Fs7zjyH7G5oD5RjVWxFrx2au0YfQXbeDgzjtFE55O0p1XsuaXOwFbYqJq9wTjSrD5ZlBH8we3kf5QgOGF2SGn2wl0KaG07vOH7iRO8s7Nvo2wFh9elb5eO4MoORRUmKItChhLMckTzitrtj1NW5lEccfDfJ7VQDLyaM6Kbxl6TJ6hWFw8OI8zZWXEvdGcHyu4MP1TgTLQzuiPZoQoH6XTTDid1WorVXw%3D%3D
# 14:50:30,329 DEBUG [org.keycloak.testsuite.util.SamlClient$RedirectStrategyWithSwitchableFollowRedirect] Redirect requested to location 'https://localhost:8543/auth/realms/demo/login-actions/first-broker-login?client_id=http%3A%2F%2Flocalhost%3A8280%2Fsales-post%2F&tab_id=sn5avG0dEog'
# 14:50:30,340 INFO  [org.keycloak.testsuite.util.SamlClient] Landed to https://localhost:8543/auth/realms/demo/login-actions/first-broker-login?client_id=http%3A%2F%2Flocalhost%3A8280%2Fsales-post%2F&tab_id=sn5avG0dEog
# 14:50:30,340 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 4: class org.keycloak.testsuite.util.saml.UpdateProfileBuilder
# 14:50:30,341 DEBUG [org.keycloak.testsuite.util.SamlClient] Disabling following redirects
# 14:50:30,341 INFO  [org.keycloak.testsuite.util.SamlClient] Executing HTTP request to https://localhost:8543/auth/realms/demo/login-actions/first-broker-login?session_code=9yuHtR4KOwDp7M6rOd7e7LSi5-odYN3x-b09IicUP7A&execution=2ac63b92-d65e-4be1-87c3-667fa3f4016b&client_id=http%3A%2F%2Flocalhost%3A8280%2Fsales-post%2F&tab_id=sn5avG0dEog
# 14:50:30,346 INFO  [org.keycloak.testsuite.util.SamlClient] Landed to https://localhost:8543/auth/realms/demo/login-actions/first-broker-login?session_code=9yuHtR4KOwDp7M6rOd7e7LSi5-odYN3x-b09IicUP7A&execution=2ac63b92-d65e-4be1-87c3-667fa3f4016b&client_id=http%3A%2F%2Flocalhost%3A8280%2Fsales-post%2F&tab_id=sn5avG0dEog
# 14:50:30,346 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 6: class org.keycloak.testsuite.util.SamlClientBuilder$$Lambda$2258/0x000000084198b440
# 14:50:30,346 DEBUG [org.keycloak.testsuite.util.SamlClient] Disabling following redirects
# 14:50:30,346 INFO  [org.keycloak.testsuite.util.SamlClient] Executing HTTP request to https://localhost:8543/auth/realms/demo/broker/after-first-broker-login?session_code=BFVfN_59eRQFcjVdDJ_8C_rX9csqPC2adtpvS-pGFoM&client_id=http%3A%2F%2Flocalhost%3A8280%2Fsales-post%2F&tab_id=sn5avG0dEog
# 14:50:30,361 INFO  [org.keycloak.testsuite.util.SamlClient] Landed to https://localhost:8543/auth/realms/demo/broker/after-first-broker-login?session_code=BFVfN_59eRQFcjVdDJ_8C_rX9csqPC2adtpvS-pGFoM&client_id=http%3A%2F%2Flocalhost%3A8280%2Fsales-post%2F&tab_id=sn5avG0dEog
# 14:50:30,361 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 8: class org.keycloak.testsuite.util.saml.ModifySamlResponseStepBuilder
# 14:50:30,363 INFO  [org.keycloak.testsuite.util.SamlClient] Last step returned no request, continuing with next step.
# 14:50:30,363 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 9: class org.keycloak.testsuite.util.saml.CreateLogoutRequestStepBuilder
# 14:50:30,365 DEBUG [org.keycloak.testsuite.util.saml.SamlDocumentStepBuilder]   ---> <samlp:LogoutRequest xmlns:samlp="urn:oasis:names:tc:SAML:2.0:protocol" xmlns:saml="urn:oasis:names:tc:SAML:2.0:assertion" xmlns="urn:oasis:names:tc:SAML:2.0:assertion" ID="ID_c20e0d44-1280-4713-931d-a34eb6d7773e" Version="2.0" IssueInstant="2021-06-07T14:50:30.363Z"><saml:Issuer>http://localhost:8280/sales-post/</saml:Issuer><saml:NameID Format="urn:oasis:names:tc:SAML:2.0:nameid-format:transient">G-368971ab-646b-4d0c-bd20-1f41599178d9</saml:NameID><samlp:SessionIndex>41015faf-0a59-4cea-b16a-bc9a2d27ed89::7b6dde9b-95a6-4600-be58-74837fcaa4af</samlp:SessionIndex></samlp:LogoutRequest>
# 14:50:30,365 DEBUG [org.keycloak.testsuite.util.SamlClient] Disabling following redirects
# 14:50:30,365 INFO  [org.keycloak.testsuite.util.SamlClient] Executing HTTP request to https://localhost:8543/auth/realms/demo/protocol/saml
# 14:50:30,376 INFO  [org.keycloak.testsuite.util.SamlClient] Landed to https://localhost:8543/auth/realms/demo/protocol/saml
# 14:50:30,376 INFO  [org.keycloak.testsuite.util.SamlClient] Running step 11: class org.keycloak.testsuite.util.SamlClientBuilder$$Lambda$2255/0x000000084198a040
# 14:50:30,377 INFO  [org.keycloak.testsuite.util.SamlClient] Last step returned no request, continuing with next step.
# 14:50:30,377 INFO  [org.keycloak.testsuite.util.SamlClient] Going to extract response
# 14:50:30,408 INFO  [org.keycloak.testsuite.saml.LogoutTest] removing test realms after test method
# 14:50:30,408 INFO  [org.keycloak.testsuite.saml.LogoutTest] removing realm: demo
# 14:50:30,651 INFO  [org.keycloak.testsuite.saml.LogoutTest] [LogoutTest] testLogoutDestinationOptionalIfUnsignedPost() FINISHED
#
#
# 14:50:30,651 INFO  [org.keycloak.testsuite.saml.LogoutTest] [LogoutTest] testLogoutMandatoryDestinationUnsetRedirect() STARTED
# 14:50:30,844 DEBUG [org.keycloak.testsuite.saml.LogoutTest] loading test realms
# Loaded realm demo
# 14:50:30,845 INFO  [org.keycloak.testsuite.saml.LogoutTest] importing test realms
# 14:50:30,845 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying demo for SSL
# 14:50:30,845 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/missing-assertion-sig/
# 14:50:30,845 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/bad-assertion-sales-post-sig/
# 14:50:30,845 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/input-portal/
# 14:50:30,845 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-assertion-and-response-sig/
# 14:50:30,845 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post2/
# 14:50:30,845 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/different-cookie-name/
# 14:50:30,845 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post/
# 14:50:30,845 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-clock-skew/
# 14:50:30,845 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-passive/
# 14:50:30,845 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-sig/
# 14:50:30,845 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-sig-transient/
# 14:50:30,845 DEBUG [org.keycloak.testsuite.saml.LogoutTest] Modifying attributes of SAML client: http://localhost:8280/sales-post-sig-persistent/
# ...
# 14:55:10,826 INFO  [org.keycloak.testsuite.x509.X509OCSPResponderTest] removing realm: test
# 14:55:11,045 INFO  [org.keycloak.testsuite.x509.X509OCSPResponderTest] [X509OCSPResponderTest] loginFailedOnOCSPResponderRevocationCheck() FINISHED
#
#
# [INFO  - 2021-06-07T14:55:11.053Z] ShutdownReqHand - _handle - About to shutdown
# [INFO] Tests run: 4, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 11.732 s - in org.keycloak.testsuite.x509.X509OCSPResponderTest
# 14:55:11,136 INFO  [org.keycloak.testsuite.arquillian.undertow.KeycloakOnUndertow] Stopping auth server.
# 14:55:11,137 INFO  [org.infinispan.manager.DefaultCacheManager] Stopping cache manager null on null
# 14:55:11,148 INFO  [io.undertow] stopping server: Undertow - 2.2.5.Final
# 14:55:11,150 INFO  [io.undertow] stopping server: Undertow - 2.2.5.Final
# [INFO]
# [INFO] Results:
# [INFO]
# [ERROR] Errors:
# [ERROR]   KcAdmSessionTest.test:72 » Runtime Failed to parse json
# [INFO]
# [ERROR] Tests run: 3731, Failures: 0, Errors: 1, Skipped: 198
# [INFO]
# [INFO]
# [INFO] -----< org.keycloak.testsuite:integration-arquillian-tests-other >------
# [INFO] Building Other Tests Modules 14.0.0-SNAPSHOT                     [46/52]
# [INFO] --------------------------------[ pom ]---------------------------------
# [INFO]
# [INFO] --- maven-clean-plugin:3.1.0:clean (default-clean) @ integration-arquillian-tests-other ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-java-version) @ integration-arquillian-tests-other ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven-version) @ integration-arquillian-tests-other ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven) @ integration-arquillian-tests-other ---
# [INFO]
# [INFO] --- buildnumber-maven-plugin:1.4:create (get-scm-revision) @ integration-arquillian-tests-other ---
# [INFO]
# [INFO] --- shrinkwrap-resolver-maven-plugin:3.1.4:propagate-execution-context (default) @ integration-arquillian-tests-other ---
# [INFO]
# [INFO] --- maven-source-plugin:3.1.0:jar-no-fork (attach-sources) @ integration-arquillian-tests-other ---
# [INFO]
# [INFO] --- maven-install-plugin:2.5.2:install (default-install) @ integration-arquillian-tests-other ---
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/tests/other/pom.xml to /root/.m2/repository/org/keycloak/testsuite/integration-arquillian-tests-other/14.0.0-SNAPSHOT/integration-arquillian-tests-other-14.0.0-SNAPSHOT.pom
# [INFO]
# [INFO] ----< org.keycloak.testsuite:integration-arquillian-tests-adapters >----
# [INFO] Building Adapter Tests 14.0.0-SNAPSHOT                           [47/52]
# [INFO] --------------------------------[ pom ]---------------------------------
# [INFO]
# [INFO] --- maven-clean-plugin:3.1.0:clean (default-clean) @ integration-arquillian-tests-adapters ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-java-version) @ integration-arquillian-tests-adapters ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven-version) @ integration-arquillian-tests-adapters ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven) @ integration-arquillian-tests-adapters ---
# [INFO]
# [INFO] --- buildnumber-maven-plugin:1.4:create (get-scm-revision) @ integration-arquillian-tests-adapters ---
# [INFO]
# [INFO] --- shrinkwrap-resolver-maven-plugin:3.1.4:propagate-execution-context (default) @ integration-arquillian-tests-adapters ---
# [INFO]
# [INFO] --- maven-source-plugin:3.1.0:jar-no-fork (attach-sources) @ integration-arquillian-tests-adapters ---
# [INFO]
# [INFO] --- maven-install-plugin:2.5.2:install (default-install) @ integration-arquillian-tests-adapters ---
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/tests/other/adapters/pom.xml to /root/.m2/repository/org/keycloak/testsuite/integration-arquillian-tests-adapters/14.0.0-SNAPSHOT/integration-arquillian-tests-adapters-14.0.0-SNAPSHOT.pom
# [INFO]
# [INFO] --< org.keycloak.testsuite:integration-arquillian-tests-adapters-jboss >--
# [INFO] Building Adapter Tests - JBoss 14.0.0-SNAPSHOT                   [48/52]
# [INFO] --------------------------------[ pom ]---------------------------------
# [INFO]
# [INFO] --- maven-clean-plugin:3.1.0:clean (default-clean) @ integration-arquillian-tests-adapters-jboss ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-java-version) @ integration-arquillian-tests-adapters-jboss ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven-version) @ integration-arquillian-tests-adapters-jboss ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven) @ integration-arquillian-tests-adapters-jboss ---
# [INFO]
# [INFO] --- buildnumber-maven-plugin:1.4:create (get-scm-revision) @ integration-arquillian-tests-adapters-jboss ---
# [INFO]
# [INFO] --- shrinkwrap-resolver-maven-plugin:3.1.4:propagate-execution-context (default) @ integration-arquillian-tests-adapters-jboss ---
# [INFO]
# [INFO] --- maven-source-plugin:3.1.0:jar-no-fork (attach-sources) @ integration-arquillian-tests-adapters-jboss ---
# [INFO]
# [INFO] --- maven-install-plugin:2.5.2:install (default-install) @ integration-arquillian-tests-adapters-jboss ---
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/tests/other/adapters/jboss/pom.xml to /root/.m2/repository/org/keycloak/testsuite/integration-arquillian-tests-adapters-jboss/14.0.0-SNAPSHOT/integration-arquillian-tests-adapters-jboss-14.0.0-SNAPSHOT.pom
# [INFO]
# [INFO] --< org.keycloak.testsuite:integration-arquillian-tests-adapters-karaf >--
# [INFO] Building Adapter Tests - Karaf 14.0.0-SNAPSHOT                   [49/52]
# [INFO] --------------------------------[ pom ]---------------------------------
# [INFO]
# [INFO] --- maven-clean-plugin:3.1.0:clean (default-clean) @ integration-arquillian-tests-adapters-karaf ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-java-version) @ integration-arquillian-tests-adapters-karaf ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven-version) @ integration-arquillian-tests-adapters-karaf ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven) @ integration-arquillian-tests-adapters-karaf ---
# [INFO]
# [INFO] --- buildnumber-maven-plugin:1.4:create (get-scm-revision) @ integration-arquillian-tests-adapters-karaf ---
# [INFO]
# [INFO] --- shrinkwrap-resolver-maven-plugin:3.1.4:propagate-execution-context (default) @ integration-arquillian-tests-adapters-karaf ---
# [INFO]
# [INFO] --- maven-source-plugin:3.1.0:jar-no-fork (attach-sources) @ integration-arquillian-tests-adapters-karaf ---
# [INFO]
# [INFO] --- maven-install-plugin:2.5.2:install (default-install) @ integration-arquillian-tests-adapters-karaf ---
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/tests/other/adapters/karaf/pom.xml to /root/.m2/repository/org/keycloak/testsuite/integration-arquillian-tests-adapters-karaf/14.0.0-SNAPSHOT/integration-arquillian-tests-adapters-karaf-14.0.0-SNAPSHOT.pom
# [INFO]
# [INFO] --< org.keycloak.testsuite:integration-arquillian-tests-adapters-was >--
# [INFO] Building Adapter Tests - WAS 14.0.0-SNAPSHOT                     [50/52]
# [INFO] --------------------------------[ pom ]---------------------------------
# [INFO]
# [INFO] --- maven-clean-plugin:3.1.0:clean (default-clean) @ integration-arquillian-tests-adapters-was ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-java-version) @ integration-arquillian-tests-adapters-was ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven-version) @ integration-arquillian-tests-adapters-was ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven) @ integration-arquillian-tests-adapters-was ---
# [INFO]
# [INFO] --- buildnumber-maven-plugin:1.4:create (get-scm-revision) @ integration-arquillian-tests-adapters-was ---
# [INFO]
# [INFO] --- shrinkwrap-resolver-maven-plugin:3.1.4:propagate-execution-context (default) @ integration-arquillian-tests-adapters-was ---
# [INFO]
# [INFO] --- maven-source-plugin:3.1.0:jar-no-fork (attach-sources) @ integration-arquillian-tests-adapters-was ---
# [INFO]
# [INFO] --- maven-install-plugin:2.5.2:install (default-install) @ integration-arquillian-tests-adapters-was ---
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/tests/other/adapters/was/pom.xml to /root/.m2/repository/org/keycloak/testsuite/integration-arquillian-tests-adapters-was/14.0.0-SNAPSHOT/integration-arquillian-tests-adapters-was-14.0.0-SNAPSHOT.pom
# [INFO]
# [INFO] --< org.keycloak.testsuite:integration-arquillian-tests-adapters-wls >--
# [INFO] Building Adapter Tests - WLS 14.0.0-SNAPSHOT                     [51/52]
# [INFO] --------------------------------[ pom ]---------------------------------
# [INFO]
# [INFO] --- maven-clean-plugin:3.1.0:clean (default-clean) @ integration-arquillian-tests-adapters-wls ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-java-version) @ integration-arquillian-tests-adapters-wls ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven-version) @ integration-arquillian-tests-adapters-wls ---
# [INFO]
# [INFO] --- maven-enforcer-plugin:3.0.0-M2:enforce (enforce-maven) @ integration-arquillian-tests-adapters-wls ---
# [INFO]
# [INFO] --- buildnumber-maven-plugin:1.4:create (get-scm-revision) @ integration-arquillian-tests-adapters-wls ---
# [INFO]
# [INFO] --- shrinkwrap-resolver-maven-plugin:3.1.4:propagate-execution-context (default) @ integration-arquillian-tests-adapters-wls ---
# [INFO]
# [INFO] --- maven-source-plugin:3.1.0:jar-no-fork (attach-sources) @ integration-arquillian-tests-adapters-wls ---
# [INFO]
# [INFO] --- maven-install-plugin:2.5.2:install (default-install) @ integration-arquillian-tests-adapters-wls ---
# [INFO] Installing /content/keycloak/testsuite/integration-arquillian/tests/other/adapters/wls/pom.xml to /root/.m2/repository/org/keycloak/testsuite/integration-arquillian-tests-adapters-wls/14.0.0-SNAPSHOT/integration-arquillian-tests-adapters-wls-14.0.0-SNAPSHOT.pom
# [INFO]
# [INFO] ------------------------------------------------------------------------
# [INFO] Skipping SSSD tests
# [INFO] This project has been banned from the build due to previous failures.
# [INFO] ------------------------------------------------------------------------
# [INFO] ------------------------------------------------------------------------
# [INFO] Reactor Summary for Keycloak Arquillian Integration TestSuite 14.0.0-SNAPSHOT:
# [INFO]
# [INFO] Keycloak Arquillian Integration TestSuite .......... SUCCESS [  1.498 s]
# [INFO] Test apps .......................................... SUCCESS [  0.061 s]
# [INFO] Test apps distribution ............................. SUCCESS [  2.411 s]
# [INFO] Keycloak Authz: PhotoZ  Test Parent ................ SUCCESS [  0.017 s]
# [INFO] Keycloak Authz Test: Photoz RESTful API ............ SUCCESS [  2.289 s]
# [INFO] Keycloak Authz Tests: Photoz HTML5 Client .......... SUCCESS [  0.369 s]
# [INFO] Keycloak Authz Tests: Hello World Example .......... SUCCESS [  0.051 s]
# [INFO] Keycloak Authz: Servlet Authorization Test ......... SUCCESS [  0.297 s]
# [INFO] Keycloak Authz: Simple Servlet App with Policy Enforcer SUCCESS [  0.050 s]
# [INFO] integration-arquillian-test-apps-servlets .......... SUCCESS [  1.442 s]
# [INFO] Keycloak Test App Profile JEE ...................... SUCCESS [  0.176 s]
# [INFO] integration-arquillian-test-apps-cors-parent ....... SUCCESS [  0.011 s]
# [INFO] Angular Product Portal JS .......................... SUCCESS [  0.692 s]
# [INFO] JAX-RS Database Service Using OAuth Bearer Tokens .. SUCCESS [  0.245 s]
# [INFO] Fuse Test Applications ............................. SUCCESS [  0.013 s]
# [INFO] Customer Portal - Secured in Karaf/Fuse ............ SUCCESS [  2.001 s]
# [INFO] CXF JAXRS Example - Secured in Karaf/Fuse .......... SUCCESS [  0.799 s]
# [INFO] CXF JAXRS Example - Secured in Karaf/Fuse 7 on Undertow SUCCESS [  0.375 s]
# [INFO] CXF JAXWS Example - Secured in Karaf/Fuse .......... SUCCESS [  0.419 s]
# [INFO] CXF JAXWS Example - Secured in Karaf/Fuse 7 on Undertow SUCCESS [  0.540 s]
# [INFO] Product Portal - Secured in Karaf/Fuse ............. SUCCESS [  0.548 s]
# [INFO] Product Portal - Secured in Karaf/Fuse 7 on Undertow SUCCESS [  0.552 s]
# [INFO] Camel endpoint example - Secured in Karaf/Fuse ..... SUCCESS [  0.569 s]
# [INFO] Camel endpoint example - Secured in Karaf/Fuse 7.0 on Undertow SUCCESS [  0.382 s]
# [INFO] Keycloak Fuse Example - Features ................... SUCCESS [  0.167 s]
# [INFO] Keycloak Examples - External Config ................ SUCCESS [  0.312 s]
# [INFO] spring-boot-adapter-app ............................ SUCCESS [  0.568 s]
# [INFO] Servers ............................................ SUCCESS [  0.010 s]
# [INFO] Auth Server ........................................ SUCCESS [  0.010 s]
# [INFO] Auth Server Services ............................... SUCCESS [  0.010 s]
# [INFO] Auth Server Services - Testsuite Providers ......... SUCCESS [  4.076 s]
# [INFO] Auth Server - JBoss ................................ SUCCESS [  0.011 s]
# [INFO] Test Util .......................................... SUCCESS [  1.195 s]
# [INFO] Auth Server - Undertow ............................. SUCCESS [  1.778 s]
# [INFO] App Server ......................................... SUCCESS [  0.009 s]
# [INFO] App Server - SPI ................................... SUCCESS [  0.105 s]
# [INFO] App Server - JBoss ................................. SUCCESS [  0.010 s]
# [INFO] App Server - Karaf ................................. SUCCESS [  0.033 s]
# [INFO] App Server - Tomcat ................................ SUCCESS [  0.010 s]
# [INFO] App Server - Undertow .............................. SUCCESS [  0.720 s]
# [INFO] App Server - Jetty Parent .......................... SUCCESS [  0.012 s]
# [INFO] Cache Server ....................................... SUCCESS [  0.009 s]
# [INFO] Cache Server - JBoss Family ........................ SUCCESS [  0.010 s]
# [INFO] Tests .............................................. SUCCESS [  0.127 s]
# [INFO] Base TestSuite ..................................... FAILURE [  01:29 h]
# [INFO] Other Tests Modules ................................ SUCCESS [  0.027 s]
# [INFO] Adapter Tests ...................................... SUCCESS [  0.011 s]
# [INFO] Adapter Tests - JBoss .............................. SUCCESS [  0.015 s]
# [INFO] Adapter Tests - Karaf .............................. SUCCESS [  0.009 s]
# [INFO] Adapter Tests - WAS ................................ SUCCESS [  0.017 s]
# [INFO] Adapter Tests - WLS ................................ SUCCESS [  0.009 s]
# [INFO] SSSD tests ......................................... SKIPPED
# [INFO] ------------------------------------------------------------------------
# [INFO] BUILD FAILURE
# [INFO] ------------------------------------------------------------------------
# [INFO] Total time:  01:29 h
# [INFO] Finished at: 2021-06-07T14:55:11Z
# [INFO] ------------------------------------------------------------------------
# [ERROR] Failed to execute goal org.apache.maven.plugins:maven-surefire-plugin:2.22.2:test (default-test) on project integration-arquillian-tests-base: There are test failures.
# [ERROR]
# [ERROR] Please refer to /content/keycloak/testsuite/integration-arquillian/tests/base/target/surefire-reports for the individual test results.
# [ERROR] Please refer to dump files (if any exist) [date].dump, [date]-jvmRun[N].dump and [date].dumpstream.
# [ERROR] -> [Help 1]
# [ERROR]
# [ERROR] To see the full stack trace of the errors, re-run Maven with the -e switch.
# [ERROR] Re-run Maven using the -X switch to enable full debug logging.
# [ERROR]
# [ERROR] For more information about the errors and possible solutions, please read the following articles:
# [ERROR] [Help 1] http://cwiki.apache.org/confluence/display/MAVEN/MojoFailureException
# [ERROR]
# [ERROR] After correcting the problems, you can resume the build with the command
# [ERROR]   mvn <goals> -rf :integration-arquillian-tests-base
